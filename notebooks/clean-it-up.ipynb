# %%
import pandas as pd
pd.set_option("max_columns", None)
wargame = pd.read_csv("../data/510049986/data.csv", index_col=0)

# %%
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# First of all, a quick sampling shows that `AliasName` is not a reliable indicator for names, as many names are given as nulls. This is due to localization: units whose names are localized cross-region have a special `LocalizationManager` to deal with that, which I didn't import into this dataset.

# %%
wargame['AliasName'].sample(10)
# Out:
# 1686                  null
# 1791                  null
# 766                   IGLA
# 1599                  null
# 818            9K33M2 ROMB
# 1626                  null
# 142     BRDM-2  STRZALA-1M
# 1046         T-55AM MERIDA
# 1082                 T-80B
# 546           LEOPARD AS1+
# Name: AliasName, dtype: object

# %%
wargame[wargame['AliasName'].map(lambda n: 'GR3' in n)]
# Out:
# Empty DataFrame
# Columns: [AcknowUnitType, AliasName, AutoOrientation, CanDeploySmoke, CanWinExperience, Category, ClassNameForDebug, CoutEtoile, CyclicManoeuvrability, DamageModuleID, DamageSelectorID, DeathExplosionAmmo, DescriptorId, EliteDeployableAmount, ExperienceGainBySecond, ExperienceModuleID, ExperienceSelectorID, Factory, FlyingAltitude, FuelCapacity, FuelModuleSelectorID, FuelMoveDuration, GFactorLimit, GunMuzzleSpeed, HardenedDeployableAmount, HitRollECMModifier, HitRollSizeModifier, IconeType, IsPrototype, IsTargetableAsBoat, Key, KillExperienceBonus, LateralSpeed, ManageUnitOrientation, Mass, MaxAcceleration, MaxDamages, MaxDeceleration, MaxHPForHUD, MaxInclination, MaxPacks, Maxspeed, MinimalAltitude, MotherCountry, MovementModuleID, MovementSelectorID, MovementType, NameInMenuToken, Nationalite, PositionInMenu, ProductionPrice, ProductionTime, ProductionYear, RookieDeployableAmount, RotorArea, SalvoWeaponOneIsMain, SalvoWeaponThreeIsMain, SalvoWeaponTwoIsMain, SalvosWeaponOne, SalvosWeaponThree, SalvosWeaponTwo, SpeedBonusOnRoad, StickToGround, TempsDemiTour, TerrainsToIgnoreMask, TextureForInterface, TextureMotherCountryForInterface, TextureTransportForInterface, TorqueManoeuvrability, TrainedDeployableAmount, Transporter, TurretNoneID, TurretNoneType, TurretOneID, TurretOneType, TurretThreeID, TurretThreeType, TurretTwoID, TurretTwoType, TypeForAcknow, UnitDescriptorID, UnitMovingType, UnitStealthBonus, UpgradeRequire, UpwardsSpeed, VehicleSubType, VeteranDeployableAmount, VisibilityModuleID, VisibilitySelectorID, VitesseCombat, WeaponFourAffecteParNombre, WeaponFourAffichageMenu, WeaponFourAffichageMunitionParSalve, WeaponFourAmmunitionID, WeaponFourAngleDispersion, WeaponFourArme, WeaponFourCaliber, WeaponFourCorrectedShotDispersionMultiplier, WeaponFourDescriptorId, WeaponFourDispersionAtMaxRange, ...]
# Index: []

# %% [markdown]
# Which is all fine and good, but some of the `ClassNameForDebug` entries are not very good either. What does `ROK_BlackBerets` mean!

# %% [markdown]
# 485 units are localized and 1333 are not. The most fruitful approach would be to merge these two, semantically, prefering a lowercased version of AliasName when one is available.

# %%
wargame['AliasName'].value_counts()[0], wargame['AliasName'].value_counts()[1:].sum()
# Out:
# (485, 1333)

# %%
def name(srs):
    if srs['AliasName'] != 'null':
        return srs['AliasName'].title()
    else:
        return srs['ClassNameForDebug'].replace("Unit", "").replace("_", " ")

names = wargame.apply(name, axis='columns')

# %%
names
# Out:
# 0                            Dana
# 1                       Rzp Kub-M
# 2                 2K22 Tunguska-M
# 3                   2K22 Tunguska
# 4                      2S15 Norov
# 5                     2S19 Msta-S
# 6                     2S1 Gozdzik
# 7                    2S1 Gvozdika
# 8                   2S23 Nona-Svk
# 9                   2S3M Akatsiya
# 10                   2S3 Akatsiya
# 11                     2S7M Malka
# 12                       2S7 Pion
# 13                    2S7 Piwonia
# 14                       2S9 Nona
# 15                    Groupe Cmdt
# 16                         Deprec
# 17                    Highlanders
# 18                 Motostrelki 90
# 19                    9K33M3 Romb
# 20                       9K33 Osa
# 21                    9K33 Osa-Ak
# 22                   9K33 Osa-Akm
# 23               Mt-Lb Strela-10M
# 24                       9K37 Buk
# 25                    9K37 Buk-M1
# 26               Aml 60/20 Serval
# 27                           Amos
# 28                  Amx-105 Mk.61
# 29                   Amx-13/Fl-12
#                   ...
# 1788                    Su25Ks NK
# 1789               Su25T Frogfoot
# 1790                      Su25 CZ
# 1791                Su25 Frogfoot
# 1792                Su27K Flanker
# 1793                Su27M Flanker
# 1794                   Su27SK CHI
# 1795                 Su27 Flanker
# 1796                    Su30 URSS
# 1797                    Su7BMK NK
# 1798                        Su7 B
# 1799                      Su7 BKL
# 1800                 Su7 Fitter A
# 1801               Super Etendard
# 1802           Super Etendard SEM
# 1803                  Tornado ADV
# 1804               Tornado ADV F3
# 1805                 Tornado GR1B
# 1806                  Tornado IDS
# 1807                       Yak38M
# 1808                 Yak38 Forger
# 1809                 Yak 141 URSS
# 1810     dan Canadair Starfighter
# 1811                      dan F16
# 1812                      nor F16
# 1813              nor F16 Block15
# 1814              rfa Tornado ECR
# 1815              rfa Tornado IDS
# 1816           rfa Tornado Marine
# 1817                     HEMTT E3
# dtype: object

# %%
wargame['UnitName'] = names

# %% [markdown]
# A more general op, get rid of all of those "null" strings!

# %%
import numpy as np
wargame = wargame.replace(to_replace='null', value=np.nan)

# %% [markdown]
# We need to massively reorder things. This is not trivial, and takes some thought, as there's over 300 variables!

# %%
print(list(wargame.columns))
# Out:
# ['AcknowUnitType', 'AliasName', 'AutoOrientation', 'CanDeploySmoke', 'CanWinExperience', 'Category', 'ClassNameForDebug', 'CoutEtoile', 'CyclicManoeuvrability', 'DamageModuleID', 'DamageSelectorID', 'DeathExplosionAmmo', 'DescriptorId', 'EliteDeployableAmount', 'ExperienceGainBySecond', 'ExperienceModuleID', 'ExperienceSelectorID', 'Factory', 'FlyingAltitude', 'FuelCapacity', 'FuelModuleSelectorID', 'FuelMoveDuration', 'GFactorLimit', 'GunMuzzleSpeed', 'HardenedDeployableAmount', 'HitRollECMModifier', 'HitRollSizeModifier', 'IconeType', 'IsPrototype', 'IsTargetableAsBoat', 'Key', 'KillExperienceBonus', 'LateralSpeed', 'ManageUnitOrientation', 'Mass', 'MaxAcceleration', 'MaxDamages', 'MaxDeceleration', 'MaxHPForHUD', 'MaxInclination', 'MaxPacks', 'Maxspeed', 'MinimalAltitude', 'MotherCountry', 'MovementModuleID', 'MovementSelectorID', 'MovementType', 'NameInMenuToken', 'Nationalite', 'PositionInMenu', 'ProductionPrice', 'ProductionTime', 'ProductionYear', 'RookieDeployableAmount', 'RotorArea', 'SalvoWeaponOneIsMain', 'SalvoWeaponThreeIsMain', 'SalvoWeaponTwoIsMain', 'SalvosWeaponOne', 'SalvosWeaponThree', 'SalvosWeaponTwo', 'SpeedBonusOnRoad', 'StickToGround', 'TempsDemiTour', 'TerrainsToIgnoreMask', 'TextureForInterface', 'TextureMotherCountryForInterface', 'TextureTransportForInterface', 'TorqueManoeuvrability', 'TrainedDeployableAmount', 'Transporter', 'TurretNoneID', 'TurretNoneType', 'TurretOneID', 'TurretOneType', 'TurretThreeID', 'TurretThreeType', 'TurretTwoID', 'TurretTwoType', 'TypeForAcknow', 'UnitDescriptorID', 'UnitMovingType', 'UnitStealthBonus', 'UpgradeRequire', 'UpwardsSpeed', 'VehicleSubType', 'VeteranDeployableAmount', 'VisibilityModuleID', 'VisibilitySelectorID', 'VitesseCombat', 'WeaponFourAffecteParNombre', 'WeaponFourAffichageMenu', 'WeaponFourAffichageMunitionParSalve', 'WeaponFourAmmunitionID', 'WeaponFourAngleDispersion', 'WeaponFourArme', 'WeaponFourCaliber', 'WeaponFourCorrectedShotDispersionMultiplier', 'WeaponFourDescriptorId', 'WeaponFourDispersionAtMaxRange', 'WeaponFourDispersionAtMinRange', 'WeaponFourEfficaciteSelonPortee', 'WeaponFourFX_frottement', 'WeaponFourFX_tir_sans_physic', 'WeaponFourFX_tir_tendu', 'WeaponFourFX_vitesse_de_depart', 'WeaponFourFireDescriptor', 'WeaponFourFireTriggeringProbability', 'WeaponFourGuidance', 'WeaponFourHitRollRule', 'WeaponFourIgnoreInflammabilityConditions', 'WeaponFourInterdireTirReflexe', 'WeaponFourInterfaceWeaponTexture', 'WeaponFourIsFireAndForget', 'WeaponFourIsSubAmmunition', 'WeaponFourLevel', 'WeaponFourMissileDescriptor', 'WeaponFourMissileTimeBetweenCorrections', 'WeaponFourName', 'WeaponFourNbTirParSalves', 'WeaponFourNbrProjectilesSimultanes', 'WeaponFourNeedModelChange', 'WeaponFourNoiseDissimulationMalus', 'WeaponFourPhysicalDamages', 'WeaponFourPorteeMaximale', 'WeaponFourPorteeMaximaleBateaux', 'WeaponFourPorteeMaximaleHA', 'WeaponFourPorteeMaximaleProjectile', 'WeaponFourPorteeMaximaleTBA', 'WeaponFourPorteeMinimale', 'WeaponFourPorteeMinimaleBateaux', 'WeaponFourPorteeMinimaleHA', 'WeaponFourPorteeMinimaleProjectile', 'WeaponFourPorteeMinimaleTBA', 'WeaponFourProjectileType', 'WeaponFourPuissance', 'WeaponFourRadiusSplashPhysicalDamages', 'WeaponFourRadiusSplashSuppressDamages', 'WeaponFourRandomDispersion', 'WeaponFourRayonPinned', 'WeaponFourSmokeDescriptor', 'WeaponFourSupplyCost', 'WeaponFourSuppressDamages', 'WeaponFourTempsAnimation', 'WeaponFourTempsDeVisee', 'WeaponFourTempsEntreDeuxFx', 'WeaponFourTempsEntreDeuxSalves', 'WeaponFourTempsEntreDeuxTirs', 'WeaponFourTirIndirect', 'WeaponFourTirReflexe', 'WeaponFourTypeArme', 'WeaponFourTypeName', 'WeaponFourWeaponCursorType', 'WeaponManagerID', 'WeaponManagerModuleSelectorID', 'WeaponOneAffecteParNombre', 'WeaponOneAffichageMenu', 'WeaponOneAffichageMunitionParSalve', 'WeaponOneAmmunitionID', 'WeaponOneAngleDispersion', 'WeaponOneAnimateOnlyOneSoldier', 'WeaponOneArme', 'WeaponOneCaliber', 'WeaponOneCorrectedShotDispersionMultiplier', 'WeaponOneDescriptorId', 'WeaponOneDispersionAtM ...

# %%
wargame[wargame['ClassNameForDebug'].map(lambda n: 'Beret' in n)]
# Out:
#      AcknowUnitType             AliasName AutoOrientation CanDeploySmoke  \
# 789              33     NIEBIESKIE BERETY            True          False
# 790              33  NIEBIESKIE BERETY 90            True          False
# 884              24            TEUKJEONSA            True          False
#
#     CanWinExperience  Category          ClassNameForDebug CoutEtoile  \
# 789             True         3     Unit_Niebieskie_Berety       null
# 790             True         3  Unit_Niebieskie_Berety_90       null
# 884             True         3       Unit_ROK_BlackBerets          2
#
#      CyclicManoeuvrability  DamageModuleID  DamageSelectorID  \
# 789                    NaN           29139             17980
# 790                    NaN           29139             17980
# 884                    NaN           27908             16675
#
#                   DeathExplosionAmmo                          DescriptorId  \
# 789  89 : 16551 (True) - TAmmunition  00000000-0000-0000-0000-00006e060000
# 790  89 : 16551 (True) - TAmmunition  00000000-0001-0000-0000-0000fd030000
# 884  89 : 16551 (True) - TAmmunition  00000000-0000-0000-0000-0000b7060000
#
#      EliteDeployableAmount  ExperienceGainBySecond  ExperienceModuleID  \
# 789                      0                     0.1               27756
# 790                      0                     0.1               27756
# 884                      3                     0.1               27756
#
#      ExperienceSelectorID  Factory  FlyingAltitude  FuelCapacity  \
# 789                 16515        6             NaN           NaN
# 790                 16515        6             NaN           NaN
# 884                 16515       10             NaN           NaN
#
#      FuelModuleSelectorID  FuelMoveDuration  GFactorLimit  GunMuzzleSpeed  \
# 789                   NaN               NaN           NaN             NaN
# 790                   NaN               NaN           NaN             NaN
# 884                   NaN               NaN           NaN             NaN
#
#      HardenedDeployableAmount HitRollECMModifier HitRollSizeModifier  \
# 789                        14               null               -0.15
# 790                        12               null               -0.15
# 884                         0               null               -0.15
#
#      IconeType IsPrototype IsTargetableAsBoat   Key  KillExperienceBonus  \
# 789          1        null               null  null                  2.5
# 790          1        null               null  null                  2.5
# 884          1        null               null  null                  2.5
#
#      LateralSpeed ManageUnitOrientation  Mass  MaxAcceleration  MaxDamages  \
# 789           NaN                  null   NaN           4030.0          15
# 790           NaN                  null   NaN           4030.0          15
# 884           NaN                  null   NaN           4030.0          10
#
#      MaxDeceleration  MaxHPForHUD  MaxInclination MaxPacks  Maxspeed  \
# 789           4030.0           15             NaN        3      1950
# 790           4030.0           15             NaN        3      1950
# 884           4030.0           10             NaN        2      2340
#
#      MinimalAltitude MotherCountry  MovementModuleID  MovementSelectorID  \
# 789              NaN           POL             27899               16666
# 790              NaN           POL             27899               16666
# 884              NaN           ROK             28207               16992
#
#                                MovementType   NameInMenuToken Nationalite  \
# 789  TMouvementHandlerLandVehicleDescriptor  AA0BE3AA7BAA2E06           1
# 790  TMouvementHandlerLandVehicleDescriptor  8192BBA7EA620000           1
# 884  TMouvementHandlerLandVehicleDescriptor  2A03A366CC541907        null
#
#      PositionInMenu ProductionPrice ProductionTime ProductionYear  \
# 789             100              25             10           1975
# 790             100              25             10           1989
# 884              97              30             10           1975
#
#      RookieDeployableAmount  RotorArea SalvoWeaponOneIsMain  \
# 789                       0        NaN                False
# 790                       0        NaN                False
# 884                       0        NaN                False
#
#     SalvoWeaponThreeIsMain SalvoWeaponTwoIsMain  SalvosWeaponOne  \
# 789                  False                False             30.0
# 790                  False                False             30.0
# 884                  False                False             20.0
#
#      SalvosWeaponThree  SalvosWeaponTwo SpeedBonusOnRoad StickToGround  \
# 789               30.0             12.0             null          True
# 790               54.0              9.0             null          True
# 884               12.0              8.0             null          True
#
#      TempsDemiTour TerrainsToIgnoreMask  \
# 789            0.1                 null
# 790            0.1                 null
# 884            0.1                 null
#
#                         TextureForInterface  \
# 789  78 : 21372 (True) - TUIResourceTexture
# 790  78 : 21378 (True) - TUIResourceTexture
# 884  78 : 21929 (True) - TUIResourceTexture
#
#        TextureMotherCountryForInterface  \
# 789                             Zoom123
# 790                             Zoom123
# 884  CommonTexture_MotherCountryFlag_UK
#
#                TextureTransportForInterface  TorqueManoeuvrability  \
# 789  78 : 21373 (True) - TUIResourceTexture                    NaN
# 790  78 : 21379 (True) - TUIResourceTexture                    NaN
# 884  78 : 21930 (True) - TUIResourceTexture                    NaN
#
#      TrainedDeployableAmount Transporter  TurretNoneID TurretNoneType  \
# 789                        0        null           NaN            NaN
# 790                        0        null           NaN            NaN
# 884                        0        null           NaN            NaN
#
#      TurretOneID                TurretOneType  TurretThreeID TurretThreeType  \
# 789      42390.0  TTurretInfanterieDescriptor            NaN             NaN
# 790      42396.0  TTurretInfanterieDescriptor            NaN             NaN
# 884      42853.0  TTurretInfanterieDescriptor            NaN             NaN
#
#      TurretTwoID                TurretTwoType  TypeForAcknow  \
# 789      42391.0  TTurretInfanterieDescriptor            125
# 790      42397.0  TTurretInfanterieDescriptor            125
# 884      42854.0  TTurretInfanterieDescriptor            125
#
#      UnitDescriptorID  UnitMovingType UnitStealthBonus UpgradeRequire  \
# 789             15461               1                2           null
# 790             15462               1                2           null
# 884             15556               1              2.5           null
#
#      UpwardsSpeed VehicleSubType  VeteranDeployableAmount  VisibilityModuleID  \
# 789           NaN              2                       10               27882
# 790           NaN              2                        8               27882
# 884           NaN              2                        4               27896
#
#      VisibilitySelectorID  VitesseCombat WeaponFourAffecteParNombre  \
# 789                 16646           1950                        NaN
# 790                 16646           1950                        NaN
# 884                 16663           2340                        NaN
#
#     WeaponFourAffichageMenu  WeaponFourAffichageMunitionParSalve  \
# 789                     NaN                                  NaN
# 790                     NaN                                  NaN
# 884                     NaN                                  NaN
#
#      WeaponFourAmmunitionID  WeaponFourAngleDispersion  WeaponFourArme  \
# 789                     NaN                        NaN             NaN
# 790                     NaN                        NaN             NaN
# 884                     NaN                        NaN             NaN
#
#     WeaponFourCaliber WeaponFourCorrectedShotDispersionMultiplier  \
# 789               NaN                                         NaN
# 790               NaN                                         NaN
# 884               NaN                                         NaN
#
#     WeaponFourDescriptorId WeaponFourDispersionAtMaxRange  \
# 789                    NaN                            NaN
# 790                    NaN                            NaN
# 884                    NaN                            NaN
#
#     WeaponFourDispersionAtMinRange WeaponFourEfficaciteSelonPortee  \
# 789                            NaN                             NaN
# 790                            NaN                             NaN
# 884                            NaN                             NaN
#
#      WeaponFourFX_frottement WeaponFourFX_tir_sans_physic  \
# 789                      NaN                          NaN
# 790                      NaN                          NaN
# 884                      NaN                          NaN
#
#     WeaponFourFX_tir_tendu  WeaponFourFX_vitesse_de_depart  \
# 789                    NaN                             NaN
# 790                    NaN                             NaN
# 884                    NaN                             NaN
#
#     WeaponFourFireDescriptor  WeaponFourFireTriggeringProbability  \
# 789                      NaN                                  NaN
# 790                      NaN                                  NaN
# 884                      NaN                                  NaN
#
#     WeaponFourGuidance WeaponFourHitRollRule  \
# 789                NaN                   NaN
# 790                NaN                   NaN
# 884                NaN                   NaN
#
#     WeaponFourIgnoreInflammabilityConditions WeaponFourInterdireTirReflexe  \
# 789                                      NaN                           NaN
# 790                                      NaN                           NaN
# 884                                      NaN                           NaN
#
#     WeaponFourInterfaceWeaponTexture WeaponFourIsFireAndForget  \
# 789                              NaN                       NaN
# 790                              NaN                       NaN
# 884                              NaN                       NaN
#
#     WeaponFourIsSubAmmunition  WeaponFourLevel WeaponFourMissileDescriptor  \
# 789                       NaN              NaN                         NaN
# 790                       NaN              NaN                         NaN
# 884                       NaN              NaN                         NaN
#
#     WeaponFourMissileTimeBetweenCorrections WeaponFourName  \
# 789                                     NaN            NaN
# 790                                     NaN            NaN
# 884                                     NaN            NaN
#
#      WeaponFourNbTirParSalves  WeaponFourNbrProjectilesSimultanes  \
# 789                       NaN                                 NaN
# 790                       NaN                                 NaN
# 884                       NaN                                 NaN
#
#     WeaponFourNeedModelChange  WeaponFourNoiseDissimulationMalus  \
# 789                       NaN                                NaN
# 790                       NaN                                NaN
# 884                       NaN                                NaN
#
#      WeaponFourPhysicalDamages  WeaponFourPorteeMaximale  \
# 789                        NaN                       NaN
# 790                        NaN                       NaN
# 884                        NaN                       NaN
#
#      WeaponFourPorteeMaximaleBateaux WeaponFourPorteeMaximaleHA  \
# 789                              NaN                        NaN
# 790                              NaN                        NaN
# 884                              NaN                        NaN
#
#     WeaponFourPorteeMaximaleProjectile  WeaponFourPorteeMaximaleTBA  \
# 789                                NaN                          NaN
# 790                                NaN                          NaN
# 884                                NaN                          NaN
#
#     WeaponFourPorteeMinimale WeaponFourPorteeMinimaleBateaux  \
# 789                      NaN                             NaN
# 790                      NaN                             NaN
# 884                      NaN                             NaN
#
#     WeaponFourPorteeMinimaleHA WeaponFourPorteeMinimaleProjectile  \
# 789                        NaN                                NaN
# 790                        NaN                                NaN
# 884                        NaN                                NaN
#
#     WeaponFourPorteeMinimaleTBA WeaponFourProjectileType  WeaponFourPuissance  \
# 789                         NaN                      NaN                  NaN
# 790                         NaN                      NaN                  NaN
# 884                         NaN                      NaN                  NaN
#
#      WeaponFourRadiusSplashPhysicalDamages  \
# 789                                    NaN
# 790                                    NaN
# 884                                    NaN
#
#      WeaponFourRadiusSplashSuppressDamages WeaponFourRandomDispersion  \
# 789                                    NaN                        NaN
# 790                                    NaN                        NaN
# 884                                    NaN                        NaN
#
#      WeaponFourRayonPinned WeaponFourSmokeDescriptor  WeaponFourSupplyCost  \
# 789                    NaN                       NaN                   NaN
# 790                    NaN                       NaN                   NaN
# 884                    NaN                       NaN                   NaN
#
#      WeaponFourSuppressDamages WeaponFourTempsAnimation  \
# 789                        NaN                      NaN
# 790                        NaN                      NaN
# 884                        NaN                      NaN
#
#      WeaponFourTempsDeVisee  WeaponFourTempsEntreDeuxFx  \
# 789                     NaN                         NaN
# 790                     NaN                         NaN
# 884                     NaN                         NaN
#
#      WeaponFourTempsEntreDeuxSalves  WeaponFourTempsEntreDeuxTirs  \
# 789                             NaN                           NaN
# 790                             NaN                           NaN
# 884                             NaN                           NaN
#
#     WeaponFourTirIndirect WeaponFourTirReflexe WeaponFourTypeArme  \
# 789                   NaN                  NaN                NaN
# 790                   NaN                  NaN                NaN
# 884                   NaN                  NaN                NaN
#
#     WeaponFourTypeName  WeaponFourWeaponCursorType  WeaponManagerID  \
# 789                NaN                         NaN          32298.0
# 790                NaN                         NaN          32303.0
# 884                NaN                         NaN          32794.0
#
#      WeaponManagerModuleSelectorID WeaponOneAffecteParNombre  \
# 789                        21369.0                      null
# 790                        21376.0                      null
# 884                        21926.0                      null
#
#     WeaponOneAffichageMenu  WeaponOneAffichageMunitionParSalve  \
# 789                   True                                 1.0
# 790                   True                                 1.0
# 884                   True                                 1.0
#
#      WeaponOneAmmunitionID  WeaponOneAngleDispersion  \
# 789                68241.0                     0.015
# 790                68457.0                     0.015
# 884                66700.0                     0.015
#
#     WeaponOneAnimateOnlyOneSoldier WeaponOneArme  WeaponOneCaliber  \
# 789                            NaN            48  DEF248B24C240000
# 790                            NaN            51  DEF248B24C240000
# 884                            NaN            52  DEF248B25C240000
#
#     WeaponOneCorrectedShotDispersionMultiplier  \
# 789                                       null
# 790                                       null
# 884                                       null
#
#                     WeaponOneDescriptorId WeaponOneDispersionAtMaxRange  \
# 789  00000000-0000-0000-0600-00006c080000                          null
# 790  00000000-0000-0000-0600-00006e080000                          null
# 884  00000000-0000-0000-0600-000097070000                          null
#
#     WeaponOneDispersionAtMinRange WeaponOneEfficaciteSelonPortee  \
# 789                          null                           null
# 790                          null                           null
# 884                          null                           null
#
#     WeaponOneFX_frottement WeaponOneFX_tir_sans_physic WeaponOneFX_tir_tendu  \
# 789                   0.01                        null                  True
# 790                   0.01                        null                  True
# 884                   0.01                        null                  True
#
#      WeaponOneFX_vitesse_de_depart WeaponOneFireDescriptor  \
# 789                        40000.0                    null
# 790                        40000.0                    null
# 884                        40000.0                    null
#
#     WeaponOneFireTriggeringProbability WeaponOneGuidance  \
# 789                               null              null
# 790                               null              null
# 884                               null              null
#
#                                 WeaponOneHitRollRule  \
# 789  113 : 77575 (False) - TModernWarfareHitRollRule
# 790  113 : 77575 (False) - TModernWarfareHitRollRule
# 884  113 : 77462 (False) - TModernWarfareHitRollRule
#
#     WeaponOneIgnoreInflammabilityConditions WeaponOneInterdireTirReflexe  \
# 789                                    null                         null
# 790                                    null                         null
# 884                                    null                         null
#
#             WeaponOneInterfaceWeaponTexture WeaponOneIsFireAndForget  \
# 789  78 : 78621 (True) - TUIResourceTexture                     null
# 790  78 : 78795 (True) - TUIResourceTexture                     null
# 884  78 : 77482 (True) - TUIResourceTexture                     null
#
#     WeaponOneIsSubAmmunition  WeaponOneLevel WeaponOneMissileDescriptor  \
# 789                     null             3.0                       null
# 790                     null             3.0                       null
# 884                     null             3.0                       null
#
#     WeaponOneMissileTimeBetweenCorrections     WeaponOneName  \
# 789                                   null  48A4710000000000
# 790                                   null  2012691C00000000
# 884                                   null  BB99E37A04000000
#
#      WeaponOneNbTirParSalves  WeaponOneNbrProjectilesSimultanes  \
# 789                      1.0                                1.0
# 790                      1.0                                1.0
# 884                      1.0                                1.0
#
#     WeaponOneNeedModelChange  WeaponOneNoiseDissimulationMalus  \
# 789                     True                              2.66
# 790                     True                              2.66
# 884                     True                              2.68
#
#     WeaponOnePhysicalDamages WeaponOnePorteeMaximale  \
# 789                        1                   52000
# 790                        1                   52000
# 884                        1                   52000
#
#     WeaponOnePorteeMaximaleBateaux WeaponOnePorteeMaximaleHA  \
# 789                          52000                      null
# 790                          52000                      null
# 884                          52000                      null
#
#     WeaponOnePorteeMaximaleProjectile WeaponOnePorteeMaximaleTBA  \
# 789                              null                       null
# 790                              null                       null
# 884                              null                       null
#
#     WeaponOnePorteeMinimale WeaponOnePorteeMinimaleBateaux  \
# 789                    null                           null
# 790                    null                           null
# 884                    null                           null
#
#     WeaponOnePorteeMinimaleHA WeaponOnePorteeMinimaleProjectile  \
# 789                      null                              null
# 790                      null                              null
# 884                      null                              null
#
#     WeaponOnePorteeMinimaleTBA WeaponOneProjectileType  WeaponOnePuissance  \
# 789                       null                    null               150.0
# 790                       null                    null               150.0
# 884                       null                    null               150.0
#
#      WeaponOneRadiusSplashPhysicalDamages  \
# 789                                 130.0
# 790                                 130.0
# 884                                 130.0
#
#      WeaponOneRadiusSplashSuppressDamages WeaponOneRandomDispersion  \
# 789                               10790.0                      null
# 790                               10790.0                      null
# 884                               10920.0                      null
#
#      WeaponOneRayonPinned WeaponOneSalvoStockIndex  \
# 789                1300.0                      NaN
# 790                1300.0                      NaN
# 884                1300.0                      NaN
#
#     WeaponOneSalvoStockIndex_ForInterface WeaponOneSmokeDescriptor  \
# 789                                   NaN                     null
# 790                                   NaN                     null
# 884                                   NaN                     null
#
#      WeaponOneSupplyCost  WeaponOneSuppressDamages WeaponOneTempsAnimation  \
# 789                 20.0                     332.0                    null
# 790                 20.0                     332.0                    null
# 884                 20.0                     336.0                    null
#
#     WeaponOneTempsDeVisee WeaponOneTempsEntreDeuxFx  \
# 789                  null                         1
# 790                  null                         1
# 884                  null                         1
#
#      WeaponOneTempsEntreDeuxSalves WeaponOneTempsEntreDeuxTirs  \
# 789                            6.0                           1
# 790                            6.0                           1
# 884                            6.0                           1
#
#     WeaponOneTirContinu WeaponOneTirEnMouvement WeaponOneTirIndirect  \
# 789                 NaN                     NaN                 null
# 790                 NaN                     NaN                 null
# 884                 NaN                     NaN                 null
#
#     WeaponOneTirReflexe WeaponOneTypeArme WeaponOneTypeName  \
# 789                True  E162010000000000  0B06000000000000
# 790                True  E162010000000000  0B06000000000000
# 884                True  E162010000000000  0B06000000000000
#
#     WeaponOneWeaponCursorType WeaponSabordAngle WeaponThreeAffecteParNombre  \
# 789                         1               NaN                         NaN
# 790                         1               NaN                         NaN
# 884                         1               NaN                         NaN
#
#     WeaponThreeAffichageMenu  WeaponThreeAffichageMunitionParSalve  \
# 789                      NaN                                   NaN
# 790                      NaN                                   NaN
# 884                      NaN                                   NaN
#
#      WeaponThreeAmmunitionID  WeaponThreeAngleDispersion  \
# 789                      NaN                         NaN
# 790                      NaN                         NaN
# 884                      NaN                         NaN
#
#     WeaponThreeAnimateOnlyOneSoldier WeaponThreeArme WeaponThreeCaliber  \
# 789                              NaN             NaN                NaN
# 790                              NaN             NaN                NaN
# 884                              NaN             NaN                NaN
#
#     WeaponThreeCorrectedShotDispersionMultiplier WeaponThreeDescriptorId  \
# 789                                          NaN                     NaN
# 790                                          NaN                     NaN
# 884                                          NaN                     NaN
#
#     WeaponThreeDispersionAtMaxRange WeaponThreeDispersionAtMinRange  \
# 789                             NaN                             NaN
# 790                             NaN                             NaN
# 884                             NaN                             NaN
#
#     WeaponThreeEfficaciteSelonPortee WeaponThreeFX_frottement  \
# 789                              NaN                      NaN
# 790                              NaN                      NaN
# 884                              NaN                      NaN
#
#     WeaponThreeFX_tir_sans_physic WeaponThreeFX_tir_tendu  \
# 789                           NaN                     NaN
# 790                           NaN                     NaN
# 884                           NaN                     NaN
#
#      WeaponThreeFX_vitesse_de_depart WeaponThreeFireDescriptor  \
# 789                              NaN                       NaN
# 790                              NaN                       NaN
# 884                              NaN                       NaN
#
#     WeaponThreeFireTriggeringProbability WeaponThreeGuidance  \
# 789                                  NaN                 NaN
# 790                                  NaN                 NaN
# 884                                  NaN                 NaN
#
#     WeaponThreeHitRollRule WeaponThreeIgnoreInflammabilityConditions  \
# 789                    NaN                                       NaN
# 790                    NaN                                       NaN
# 884                    NaN                                       NaN
#
#     WeaponThreeInterdireTirReflexe WeaponThreeInterfaceWeaponTexture  \
# 789                            NaN                               NaN
# 790                            NaN                               NaN
# 884                            NaN                               NaN
#
#     WeaponThreeIsFireAndForget WeaponThreeIsSubAmmunition  WeaponThreeLevel  \
# 789                        NaN                        NaN               NaN
# 790                        NaN                        NaN               NaN
# 884                        NaN                        NaN               NaN
#
#     WeaponThreeMissileDescriptor WeaponThreeMissileTimeBetweenCorrections  \
# 789                          NaN                                      NaN
# 790                          NaN                                      NaN
# 884                          NaN                                      NaN
#
#     WeaponThreeName  WeaponThreeNbTirParSalves  \
# 789             NaN                        NaN
# 790             NaN                        NaN
# 884             NaN                        NaN
#
#      WeaponThreeNbrProjectilesSimultanes WeaponThreeNeedModelChange  \
# 789                                  NaN                        NaN
# 790                                  NaN                        NaN
# 884                                  NaN                        NaN
#
#      WeaponThreeNoiseDissimulationMalus  WeaponThreePhysicalDamages  \
# 789                                 NaN                         NaN
# 790                                 NaN                         NaN
# 884                                 NaN                         NaN
#
#      WeaponThreePorteeMaximale  WeaponThreePorteeMaximaleBateaux  \
# 789                        NaN                               NaN
# 790                        NaN                               NaN
# 884                        NaN                               NaN
#
#     WeaponThreePorteeMaximaleHA WeaponThreePorteeMaximaleProjectile  \
# 789                         NaN                                 NaN
# 790                         NaN                                 NaN
# 884                         NaN                                 NaN
#
#     WeaponThreePorteeMaximaleTBA WeaponThreePorteeMinimale  \
# 789                          NaN                       NaN
# 790                          NaN                       NaN
# 884                          NaN                       NaN
#
#     WeaponThreePorteeMinimaleBateaux WeaponThreePorteeMinimaleHA  \
# 789                              NaN                         NaN
# 790                              NaN                         NaN
# 884                              NaN                         NaN
#
#     WeaponThreePorteeMinimaleProjectile WeaponThreePorteeMinimaleTBA  \
# 789                                 NaN                          NaN
# 790                                 NaN                          NaN
# 884                                 NaN                          NaN
#
#     WeaponThreeProjectileType  WeaponThreePuissance  \
# 789                       NaN                   NaN
# 790                       NaN                   NaN
# 884                       NaN                   NaN
#
#      WeaponThreeRadiusSplashPhysicalDamages  \
# 789                                     NaN
# 790                                     NaN
# 884                                     NaN
#
#      WeaponThreeRadiusSplashSuppressDamages WeaponThreeRandomDispersion  \
# 789                                     NaN                         NaN
# 790                                     NaN                         NaN
# 884                                     NaN                         NaN
#
#      WeaponThreeRayonPinned WeaponThreeSalvoStockIndex  \
# 789                     NaN                        NaN
# 790                     NaN                        NaN
# 884                     NaN                        NaN
#
#     WeaponThreeSalvoStockIndex_ForInterface WeaponThreeSmokeDescriptor  \
# 789                                     NaN                        NaN
# 790                                     NaN                        NaN
# 884                                     NaN                        NaN
#
#      WeaponThreeSupplyCost  WeaponThreeSuppressDamages  \
# 789                    NaN                         NaN
# 790                    NaN                         NaN
# 884                    NaN                         NaN
#
#     WeaponThreeTempsAnimation  WeaponThreeTempsDeVisee  \
# 789                       NaN                      NaN
# 790                       NaN                      NaN
# 884                       NaN                      NaN
#
#      WeaponThreeTempsEntreDeuxFx  WeaponThreeTempsEntreDeuxSalves  \
# 789                          NaN                              NaN
# 790                          NaN                              NaN
# 884                          NaN                              NaN
#
#      WeaponThreeTempsEntreDeuxTirs WeaponThreeTirContinu  \
# 789                            NaN                   NaN
# 790                            NaN                   NaN
# 884                            NaN                   NaN
#
#     WeaponThreeTirEnMouvement WeaponThreeTirIndirect WeaponThreeTirReflexe  \
# 789                       NaN                    NaN                   NaN
# 790                       NaN                    NaN                   NaN
# 884                       NaN                    NaN                   NaN
#
#     WeaponThreeTypeArme WeaponThreeTypeName  WeaponThreeWeaponCursorType  \
# 789                 NaN                 NaN                          NaN
# 790                 NaN                 NaN                          NaN
# 884                 NaN                 NaN                          NaN
#
#     WeaponTwoAffecteParNombre WeaponTwoAffichageMenu  \
# 789                      null                   True
# 790                      null                   True
# 884                      null                   True
#
#      WeaponTwoAffichageMunitionParSalve  WeaponTwoAmmunitionID  \
# 789                                80.0                68242.0
# 790                                45.0                70603.0
# 884                               200.0                68307.0
#
#      WeaponTwoAngleDispersion WeaponTwoAnimateOnlyOneSoldier WeaponTwoArme  \
# 789                      0.01                            NaN          null
# 790                      0.01                            NaN          null
# 884                      0.01                            NaN          null
#
#      WeaponTwoCaliber WeaponTwoCorrectedShotDispersionMultiplier  \
# 789  B26C14A501000000                                       null
# 790  B26C14A501000000                                       null
# 884  B27C18A501000000                                       null
#
#                     WeaponTwoDescriptorId WeaponTwoDispersionAtMaxRange  \
# 789  00000000-0000-0000-0600-0000ba040000                          null
# 790  00000000-0000-0000-0600-0000bb040000                          null
# 884  00000000-0006-0000-0600-0000f4030000                          null
#
#     WeaponTwoDispersionAtMinRange WeaponTwoEfficaciteSelonPortee  \
# 789                          null                           null
# 790                          null                           null
# 884                          null                           null
#
#     WeaponTwoFX_frottement WeaponTwoFX_tir_sans_physic WeaponTwoFX_tir_tendu  \
# 789                   0.01                        null                  True
# 790                   0.01                        null                  True
# 884                   0.01                        null                  True
#
#      WeaponTwoFX_vitesse_de_depart WeaponTwoFireDescriptor  \
# 789                       180000.0                    null
# 790                       180000.0                    null
# 884                       180000.0                    null
#
#     WeaponTwoFireTriggeringProbability WeaponTwoGuidance  \
# 789                               null              null
# 790                               null              null
# 884                               null              null
#
#                                 WeaponTwoHitRollRule  \
# 789  113 : 77437 (False) - TModernWarfareHitRollRule
# 790  113 : 77437 (False) - TModernWarfareHitRollRule
# 884  113 : 78286 (False) - TModernWarfareHitRollRule
#
#     WeaponTwoIgnoreInflammabilityConditions WeaponTwoInterdireTirReflexe  \
# 789                                    null                         null
# 790                                    null                         null
# 884                                    null                         null
#
#             WeaponTwoInterfaceWeaponTexture WeaponTwoIsFireAndForget  \
# 789  78 : 78622 (True) - TUIResourceTexture                     null
# 790  78 : 80113 (True) - TUIResourceTexture                     null
# 884  78 : 78691 (True) - TUIResourceTexture                     null
#
#     WeaponTwoIsSubAmmunition  WeaponTwoLevel WeaponTwoMissileDescriptor  \
# 789                     null             3.0                       null
# 790                     null             3.0                       null
# 884                     null             3.0                       null
#
#     WeaponTwoMissileTimeBetweenCorrections     WeaponTwoName  \
# 789                                   null  4851691C00000000
# 790                                   null  0552691C00000000
# 884                                   null  AEECCEEE05000000
#
#      WeaponTwoNbTirParSalves  WeaponTwoNbrProjectilesSimultanes  \
# 789                      8.0                                1.0
# 790                      5.0                                1.0
# 884                     20.0                                1.0
#
#     WeaponTwoNeedModelChange  WeaponTwoNoiseDissimulationMalus  \
# 789                     null                              2.25
# 790                     null                              2.25
# 884                     null                              2.25
#
#      WeaponTwoPhysicalDamages WeaponTwoPorteeMaximale  \
# 789                       0.5                   57200
# 790                       0.5                   57200
# 884                       0.5                   57200
#
#     WeaponTwoPorteeMaximaleBateaux WeaponTwoPorteeMaximaleHA  \
# 789                          57200                      null
# 790                          57200                      null
# 884                          57200                      null
#
#     WeaponTwoPorteeMaximaleProjectile WeaponTwoPorteeMaximaleTBA  \
# 789                              null                      44200
# 790                              null                      44200
# 884                              null                      44200
#
#     WeaponTwoPorteeMinimale WeaponTwoPorteeMinimaleBateaux  \
# 789                    null                           null
# 790                    null                           null
# 884                    null                           null
#
#     WeaponTwoPorteeMinimaleHA WeaponTwoPorteeMinimaleProjectile  \
# 789                      null                              null
# 790                      null                              null
# 884                      null                              null
#
#     WeaponTwoPorteeMinimaleTBA WeaponTwoProjectileType  WeaponTwoPuissance  \
# 789                       null                    null                16.0
# 790                       null                    null                16.0
# 884                       null                    null                16.0
#
#      WeaponTwoRadiusSplashPhysicalDamages  \
# 789                                 156.0
# 790                                 130.0
# 884                                 130.0
#
#      WeaponTwoRadiusSplashSuppressDamages WeaponTwoRandomDispersion  \
# 789                                2600.0                      null
# 790                                2600.0                      null
# 884                                2600.0                      null
#
#      WeaponTwoRayonPinned WeaponTwoSalvoStockIndex  \
# 789                 260.0                      NaN
# 790                 260.0                      NaN
# 884                 260.0                      NaN
#
#     WeaponTwoSalvoStockIndex_ForInterface WeaponTwoSmokeDescriptor  \
# 789                                   NaN                     null
# 790                                   NaN                     null
# 884                                   NaN                     null
#
#      WeaponTwoSupplyCost  WeaponTwoSuppressDamages WeaponTwoTempsAnimation  \
# 789                  8.0                      40.0                    null
# 790                  5.0                      40.0                    null
# 884                 20.0                      40.0                    null
#
#     WeaponTwoTempsDeVisee  WeaponTwoTempsEntreDeuxFx  \
# 789                     2                        0.2
# 790                     2                        0.2
# 884                     2                        0.2
#
#      WeaponTwoTempsEntreDeuxSalves  WeaponTwoTempsEntreDeuxTirs  \
# 789                            4.0                          0.8
# 790                            2.0                          0.8
# 884                            5.0                          0.8
#
#     WeaponTwoTirContinu WeaponTwoTirEnMouvement WeaponTwoTirIndirect  \
# 789                 NaN                     NaN                 null
# 790                 NaN                     NaN                 null
# 884                 NaN                     NaN                 null
#
#     WeaponTwoTirReflexe WeaponTwoTypeArme WeaponTwoTypeName  \
# 789                True  E1D2010000000000  0B06000000000000
# 790                True  E1D2010000000000  0B06000000000000
# 884                True  E1D2010000000000  0B06000000000000
#
#     WeaponTwoWeaponCursorType                    _ShortDatabaseName
# 789                         6     Descriptor_Unit_Niebieskie_Berety
# 790                         6  Descriptor_Unit_Niebieskie_Berety_90
# 884                         6       Descriptor_Unit_ROK_BlackBerets

# %%
leading_cols = ['UnitName', 'MotherCountry', 'ProductionPrice', 'ProductionYear',
                'MaxDamages', 'IsPrototype',
                'ManageUnitOrientation', 'CanDeploySmoke', 
                'CanWinExperience', 'ExperienceGainBySecond',
                'UnitMovingType', 'MovementType', 'SpeedBonusOnRoad', 'Maxspeed', 'FuelCapacity', 'FuelMoveDuration',
                'Transporter', 'IsTargetableAsBoat', 'TerrainsToIgnoreMask',
                'RookieDeployableAmount', 'TrainedDeployableAmount', 'HardenedDeployableAmount',
                'VeteranDeployableAmount', 'EliteDeployableAmount',
                'UnitStealthBonus', 'HitRollSizeModifier', 'HitRollECMModifier',
                'Maxspeed', 'UnitMovingType', 'FlyingAltitude', 'MinimalAltitude', 'GunMuzzleSpeed',
                'CyclicManoeuvrability', 'GFactorLimit', 'LateralSpeed', 'Mass', 'MaxInclination',
                'RotorArea', 'TorqueManoeuvrability', 'UpwardsSpeed', 'TempsDemiTour',
                'MaxAcceleration', 'MaxDeceleration', 'WeaponSabordAngle',
                'AliasName', 'ClassNameForDebug', '_ShortDatabaseName', 'NameInMenuToken',
                'Factory', 'IconeType', 'MaxPacks', 'Nationalite', 'PositionInMenu', 'TypeForAcknow',
                'VehicleSubType', 'Key', 'CoutEtoile', 'UpgradeRequire',                
                'ProductionTime',
                'Category', 'AcknowUnitType', 'TypeForAcknow', 'DescriptorId',
                'MaxHPForHUD',                
               ]
nonleading_cols = list(set(wargame.columns) - set(leading_cols))
wargame = wargame.reindex(columns=leading_cols + nonleading_cols)

# %%
wargame['IsPrototype'] = wargame['IsPrototype'].map(lambda v: True if pd.notnull(v) else False)

# %%
wargame['MotherCountry'].value_counts()
# Out:
# URSS    205
# US      173
# POL     108
# RDA     106
# CHI     101
# NK      100
# TCH      97
# ISR      96
# UK       95
# FR       92
# RFA      88
# ROK      80
# HOL      80
# ANZ      72
# CAN      71
# SWE      67
# JAP      66
# DAN      61
# NOR      60
# Name: MotherCountry, dtype: int64

# %%
wargame[wargame['MotherCountry'] == 'RFA'].head()
# Out:
#               UnitName MotherCountry ProductionPrice ProductionYear  \
# 190                Bgs           RFA              10           1975
# 235  Pzbefwg Leopard 2           RFA             170           1979
# 323    Sonderwagen Iii           RFA              20           1966
# 333         Fernspaher           RFA              25           1975
# 338       Frr Roland 3           RFA              65           1988
#
#      MaxDamages IsPrototype ManageUnitOrientation CanDeploySmoke  \
# 190           5       False                   NaN          False
# 235          10       False                  True          False
# 323          10       False                  True          False
# 333           2       False                   NaN          False
# 338          10       False                  True          False
#
#     CanWinExperience  ExperienceGainBySecond  UnitMovingType  \
# 190             True                     0.1               1
# 235             True                     0.1               5
# 323             True                     0.1               3
# 333             True                     0.1               1
# 338             True                     0.1               3
#
#                                MovementType SpeedBonusOnRoad  Maxspeed  \
# 190  TMouvementHandlerLandVehicleDescriptor              NaN      1170
# 235  TMouvementHandlerLandVehicleDescriptor        0.5714286      3640
# 323  TMouvementHandlerLandVehicleDescriptor         1.142857      3640
# 333  TMouvementHandlerLandVehicleDescriptor              NaN      2340
# 338  TMouvementHandlerLandVehicleDescriptor            0.875      4160
#
#      FuelCapacity  FuelMoveDuration Transporter IsTargetableAsBoat  \
# 190           NaN               NaN         NaN                NaN
# 235        1200.0             550.0         NaN                NaN
# 323          80.0             400.0         NaN                NaN
# 333           NaN               NaN         NaN                NaN
# 338         500.0             600.0         NaN                NaN
#
#     TerrainsToIgnoreMask  RookieDeployableAmount  TrainedDeployableAmount  \
# 190                  NaN                      12                        8
# 235                  NaN                       0                        0
# 323                  NaN                       0                       12
# 333                  NaN                       0                        0
# 338                  NaN                       0                        4
#
#      HardenedDeployableAmount  VeteranDeployableAmount  EliteDeployableAmount  \
# 190                         0                        0                      0
# 235                         3                        2                      0
# 323                         8                        0                      0
# 333                         0                        4                      3
# 338                         3                        0                      0
#
#     UnitStealthBonus HitRollSizeModifier HitRollECMModifier  Maxspeed  \
# 190                2               -0.15                NaN      1170
# 235                1                0.05                NaN      3640
# 323              1.5               -0.05                NaN      3640
# 333                3               -0.15                NaN      2340
# 338                1                 NaN                NaN      4160
#
#      UnitMovingType  FlyingAltitude  MinimalAltitude  GunMuzzleSpeed  \
# 190               1             NaN              NaN             NaN
# 235               5             NaN              NaN             NaN
# 323               3             NaN              NaN             NaN
# 333               1             NaN              NaN             NaN
# 338               3             NaN              NaN             NaN
#
#      CyclicManoeuvrability  GFactorLimit  LateralSpeed  Mass  MaxInclination  \
# 190                    NaN           NaN           NaN   NaN             NaN
# 235                    NaN           NaN           NaN   NaN             NaN
# 323                    NaN           NaN           NaN   NaN             NaN
# 333                    NaN           NaN           NaN   NaN             NaN
# 338                    NaN           NaN           NaN   NaN             NaN
#
#      RotorArea  TorqueManoeuvrability  UpwardsSpeed  TempsDemiTour  \
# 190        NaN                    NaN           NaN            0.1
# 235        NaN                    NaN           NaN            4.0
# 323        NaN                    NaN           NaN            3.0
# 333        NaN                    NaN           NaN            0.1
# 338        NaN                    NaN           NaN            3.0
#
#      MaxAcceleration  MaxDeceleration WeaponSabordAngle          AliasName  \
# 190           4030.0           4030.0               NaN                BGS
# 235           1300.0           2600.0               NaN  PzBefWg LEOPARD 2
# 323           1300.0           2600.0               NaN    SONDERWAGEN III
# 333           4030.0           4030.0               NaN         FERNSPAHER
# 338           1950.0           2600.0               NaN       FRR ROLAND 3
#
#             ClassNameForDebug                   _ShortDatabaseName  \
# 190  Unit_Bundesgrenzschutzen  Descriptor_Unit_Bundesgrenzschutzen
# 235        Unit_CMD_Leopard_2        Descriptor_Unit_CMD_Leopard_2
# 323    Unit_FV601_Saladin_ANZ    Descriptor_Unit_FV601_Saladin_ANZ
# 333           Unit_Fernspaher           Descriptor_Unit_Fernspaher
# 338   Unit_FlaRakRad_ROLAND_2   Descriptor_Unit_FlaRakRad_ROLAND_2
#
#       NameInMenuToken  Factory  IconeType MaxPacks Nationalite  \
# 190  B37AB3B89ACE3A03       10          1        1         NaN
# 235  E96DD6B46A395703        3          1        1         NaN
# 323  24B6CC6E6AC66607       10          1        2         NaN
# 333  B7DA9A353EDF2A04       10          1        2         NaN
# 338  5C6A72B0C9993104       13          3        2         NaN
#
#      PositionInMenu  TypeForAcknow VehicleSubType  Key CoutEtoile  \
# 190              96            125              2  NaN          1
# 235              43            108            NaN  NaN          7
# 323               2            109              1  NaN        NaN
# 333              96            125              2  NaN          2
# 338               8            123              1  NaN          2
#
#                                 UpgradeRequire ProductionTime  Category  \
# 190                                        NaN             10         3
# 235  81 : 15196 (True) - TUniteAuSolDescriptor             10         3
# 323                                        NaN             10         1
# 333                                        NaN             10         3
# 338                                        NaN             10         5
#
#      AcknowUnitType  TypeForAcknow                          DescriptorId  \
# 190              24            125  00000000-0000-0000-0000-00008f040000
# 235              22            108  00000000-0000-0000-0000-0000bc040000
# 323              24            109  00000000-0000-0000-0000-000005050000
# 333              24            125  00000000-0000-0000-0000-00000e050000
# 338              30            123  00000000-0000-0000-0000-000013050000
#
#      MaxHPForHUD WeaponThreeFX_frottement WeaponTwoPorteeMinimale  \
# 190            5                      NaN                     NaN
# 235           10                      NaN                     NaN
# 323           10                      NaN                     NaN
# 333            2                      NaN                    6500
# 338           10                      NaN                     NaN
#
#      WeaponFourPorteeMinimaleBateaux  WeaponThreeInterdireTirReflexe  \
# 190                              NaN                             NaN
# 235                              NaN                             NaN
# 323                              NaN                             NaN
# 333                              NaN                             NaN
# 338                              NaN                             NaN
#
#     WeaponTwoSalvoStockIndex_ForInterface  WeaponThreeTempsAnimation  \
# 190                                   NaN                        NaN
# 235                                   NaN                        NaN
# 323                                   NaN                        NaN
# 333                                   NaN                        NaN
# 338                                   NaN                        NaN
#
#     WeaponTwoIsFireAndForget  WeaponTwoSuppressDamages  \
# 190                      NaN                      55.0
# 235                      NaN                     138.0
# 323                      NaN                      88.0
# 333                      NaN                      55.0
# 338                      NaN                       NaN
#
#     WeaponOneDispersionAtMinRange WeaponTwoTempsDeVisee  \
# 190                           NaN                   1.4
# 235                           NaN                   1.4
# 323                           NaN                   1.4
# 333                           NaN                     2
# 338                           NaN                   NaN
#
#     WeaponOneSalvoStockIndex WeaponTwoTypeName  WeaponManagerModuleSelectorID  \
# 190                      NaN  0B06000000000000                        17780.0
# 235                      NaN  0B06000000000000                        18087.0
# 323                      NaN  0B06000000000000                        18643.0
# 333                      NaN  0B06000000000000                        18706.0
# 338                      NaN               NaN                        18737.0
#
#     WeaponTwoTirReflexe  WeaponOneNoiseDissimulationMalus  \
# 190                True                             3.000
# 235                True                             1.762
# 323                True                             1.760
# 333                True                             2.320
# 338                 NaN                             2.000
#
#      WeaponThreeSalvoStockIndex_ForInterface  WeaponFourFX_tir_sans_physic  \
# 190                                      NaN                           NaN
# 235                                      NaN                           NaN
# 323                                      NaN                           NaN
# 333                                      NaN                           NaN
# 338                                      NaN                           NaN
#
#      WeaponOneRayonPinned  WeaponFourPorteeMinimaleHA  \
# 190                1300.0                         NaN
# 235                 260.0                         NaN
# 323                2080.0                         NaN
# 333                1300.0                         NaN
# 338               26000.0                         NaN
#
#      WeaponTwoPorteeMinimaleTBA WeaponOnePorteeMaximaleTBA  \
# 190                         NaN                        NaN
# 235                         NaN                      39000
# 323                         NaN                        NaN
# 333                         NaN                        NaN
# 338                         NaN                     208000
#
#     WeaponOnePorteeMaximale  WeaponFourInterdireTirReflexe  \
# 190                   39000                            NaN
# 235                   65000                            NaN
# 323                  117000                            NaN
# 333                   39000                            NaN
# 338                     NaN                            NaN
#
#      KillExperienceBonus WeaponOneFX_tir_sans_physic  \
# 190                  2.5                         NaN
# 235                  2.5                         NaN
# 323                  2.5                         NaN
# 333                  2.5                         NaN
# 338                  2.5                        True
#
#                         TextureForInterface  WeaponFourTempsEntreDeuxSalves  \
# 190  78 : 17783 (True) - TUIResourceTexture                             NaN
# 235  78 : 18090 (True) - TUIResourceTexture                             NaN
# 323  78 : 18644 (True) - TUIResourceTexture                             NaN
# 333  78 : 18709 (True) - TUIResourceTexture                             NaN
# 338  78 : 18741 (True) - TUIResourceTexture                             NaN
#
#     WeaponFourCaliber  WeaponThreePorteeMinimaleProjectile  \
# 190               NaN                                  NaN
# 235               NaN                                  NaN
# 323               NaN                                  NaN
# 333               NaN                                  NaN
# 338               NaN                                  NaN
#
#     WeaponOneIgnoreInflammabilityConditions  WeaponTwoSmokeDescriptor  \
# 190                                     NaN                       NaN
# 235                                     NaN                       NaN
# 323                                     NaN                       NaN
# 333                                     NaN                       NaN
# 338                                     NaN                       NaN
#
#     WeaponThreeMissileTimeBetweenCorrections  WeaponOneAmmunitionID  \
# 190                                      NaN                67691.0
# 235                                      NaN                67953.0
# 323                                      NaN                68428.0
# 333                                      NaN                66973.0
# 338                                      NaN                66907.0
#
#     WeaponOneTempsDeVisee WeaponOneGuidance WeaponTwoFX_frottement  \
# 190                   NaN               NaN                   0.01
# 235                     1               NaN                   0.01
# 323                     1               NaN                   0.01
# 333                   NaN               NaN                   0.01
# 338                   0.2                 1                    NaN
#
#     WeaponThreeDescriptorId  WeaponOneInterdireTirReflexe  \
# 190                     NaN                           NaN
# 235                     NaN                           NaN
# 323                     NaN                           NaN
# 333                     NaN                           NaN
# 338                     NaN                           NaN
#
#      WeaponThreeIsFireAndForget  VisibilitySelectorID WeaponOneFireDescriptor  \
# 190                         NaN                 16646                     NaN
# 235                         NaN                 16517                     NaN
# 323                         NaN                 16764                     NaN
# 333                         NaN                 17895                     NaN
# 338                         NaN                 16517                     NaN
#
#      WeaponOneCaliber WeaponFourTypeArme WeaponTwoPorteeMaximaleTBA  \
# 190  DEF248B21C040200                NaN                        NaN
# 235  B23C1C2502000000                NaN                        NaN
# 323  DEF248B27C200000                NaN                        NaN
# 333  DEF248B27C1C0000                NaN                      44200
# 338  B7999A1C00000000                NaN                        NaN
#
#      WeaponTwoRayonPinned  WeaponTwoCaliber  \
# 190                 260.0  B23C1C2502000000
# 235                7800.0  B21C0C0200000000
# 323                7800.0  B27C200000000000
# 333                 260.0  B23C1C2502000000
# 338                   NaN               NaN
#
#      WeaponOneRadiusSplashSuppressDamages WeaponTwoFX_tir_tendu  \
# 190                               13000.0                  True
# 235                                 520.0                  True
# 323                                9880.0                  True
# 333                                8580.0                  True
# 338                               21840.0                   NaN
#
#     WeaponTwoTypeArme            WeaponOneMissileDescriptor  \
# 190  6ABCBA1C00000000                                   NaN
# 235  B31E95B36B5E0000                                   NaN
# 323  B31E95B36B5E0000                                   NaN
# 333  B75ABB7307000000                                   NaN
# 338               NaN  82 : 77630 (True) - TUniteDescriptor
#
#     WeaponOneTirContinu WeaponThreePorteeMinimale WeaponOneProjectileType  \
# 190                 NaN                       NaN                     NaN
# 235                 NaN                       NaN                     NaN
# 323                 NaN                       NaN                     NaN
# 333                 NaN                       NaN                     NaN
# 338                 NaN                       NaN                       5
#
#      WeaponFourPorteeMaximaleProjectile WeaponThreeEfficaciteSelonPortee  \
# 190                                 NaN                              NaN
# 235                                 NaN                              NaN
# 323                                 NaN                              NaN
# 333                                 NaN                              NaN
# 338                                 NaN                              NaN
#
#      TurretTwoID  WeaponFourAngleDispersion WeaponTwoAffecteParNombre  \
# 190      39402.0                        NaN                      True
# 235      39640.0                        NaN                       NaN
# 323          NaN                        NaN                       NaN
# 333      40158.0                        NaN                       NaN
# 338          NaN                        NaN                       NaN
#
#      WeaponThreePorteeMaximaleBateaux WeaponThreeName  \
# 190                               NaN             NaN
# 235                               NaN             NaN
# 323                               NaN             NaN
# 333                               NaN             NaN
# 338                               NaN             NaN
#
#     WeaponTwoNeedModelChange WeaponOneFireTriggeringProbability  \
# 190                      NaN                                NaN
# 235                      NaN                                NaN
# 323                      NaN                                NaN
# 333                     True                                NaN
# 338                      NaN                                NaN
#
#         WeaponOneName WeaponOnePorteeMinimaleHA  \
# 190  B31B334462710000                       NaN
# 235  44740D0702000000                       NaN
# 323  8675200000000000                       NaN
# 333  E1620DC805000000                       NaN
# 338  443A9B31CD010000                       NaN
#
#      WeaponFourFireTriggeringProbability WeaponOneWeaponCursorType  \
# 190                                  NaN                         1
# 235                                  NaN                         6
# 323                                  NaN                         4
# 333                                  NaN                         1
# 338                                  NaN                         3
#
#      WeaponFourIsFireAndForget WeaponThreeTypeName  \
# 190                        NaN                 NaN
# 235                        NaN                 NaN
# 323                        NaN                 NaN
# 333                        NaN                 NaN
# 338                        NaN                 NaN
#
#      WeaponThreeTempsEntreDeuxFx  WeaponThreeTempsEntreDeuxTirs  \
# 190                          NaN                            NaN
# 235                          NaN                            NaN
# 323                          NaN                            NaN
# 333                          NaN                            NaN
# 338                          NaN                            NaN
#
#      WeaponThreeTempsEntreDeuxSalves  WeaponOnePuissance  \
# 190                              NaN               150.0
# 235                              NaN                16.0
# 323                              NaN               250.0
# 333                              NaN               150.0
# 338                              NaN               500.0
#
#     WeaponThreeProjectileType TurretNoneType  WeaponThreeFX_vitesse_de_depart  \
# 190                       NaN            NaN                              NaN
# 235                       NaN            NaN                              NaN
# 323                       NaN            NaN                              NaN
# 333                       NaN            NaN                              NaN
# 338                       NaN            NaN                              NaN
#
#     SalvoWeaponOneIsMain WeaponFourInterfaceWeaponTexture  \
# 190                False                              NaN
# 235                False                              NaN
# 323                False                              NaN
# 333                False                              NaN
# 338                False                              NaN
#
#     WeaponThreeMissileDescriptor  WeaponFourTempsAnimation  \
# 190                          NaN                       NaN
# 235                          NaN                       NaN
# 323                          NaN                       NaN
# 333                          NaN                       NaN
# 338                          NaN                       NaN
#
#      WeaponThreePuissance  WeaponFourPorteeMinimaleTBA  \
# 190                   NaN                          NaN
# 235                   NaN                          NaN
# 323                   NaN                          NaN
# 333                   NaN                          NaN
# 338                   NaN                          NaN
#
#      WeaponThreeRayonPinned WeaponThreeFireDescriptor  WeaponThreeTirContinu  \
# 190                     NaN                       NaN                    NaN
# 235                     NaN                       NaN                    NaN
# 323                     NaN                       NaN                    NaN
# 333                     NaN                       NaN                    NaN
# 338                     NaN                       NaN                    NaN
#
#     WeaponOneFX_tir_tendu  WeaponFourWeaponCursorType  \
# 190                  True                         NaN
# 235                  True                         NaN
# 323                  True                         NaN
# 333                  True                         NaN
# 338                   NaN                         NaN
#
#     WeaponOneIsSubAmmunition WeaponOneAnimateOnlyOneSoldier  \
# 190                      NaN                            NaN
# 235                      NaN                            NaN
# 323                      NaN                            NaN
# 333                      NaN                            NaN
# 338                      NaN                            NaN
#
#     WeaponThreePorteeMinimaleBateaux  TurretNoneID WeaponTwoProjectileType  \
# 190                              NaN           NaN                     NaN
# 235                              NaN           NaN                     NaN
# 323                              NaN           NaN                     NaN
# 333                              NaN           NaN                     NaN
# 338                              NaN           NaN                     NaN
#
#      WeaponFourProjectileType WeaponTwoWeaponCursorType  \
# 190                       NaN                         6
# 235                       NaN                         4
# 323                       NaN                         4
# 333                       NaN                         6
# 338                       NaN                       NaN
#
#      WeaponFourSuppressDamages WeaponOnePorteeMaximaleProjectile  \
# 190                        NaN                               NaN
# 235                        NaN                               NaN
# 323                        NaN                               NaN
# 333                        NaN                               NaN
# 338                        NaN                               NaN
#
#     WeaponTwoDispersionAtMinRange WeaponOneTirReflexe  \
# 190                           NaN                True
# 235                           NaN                True
# 323                           NaN                True
# 333                           NaN                True
# 338                           NaN                True
#
#      WeaponFourFX_vitesse_de_depart  WeaponThreeLevel  WeaponManagerID  \
# 190                             NaN               NaN          28965.0
# 235                             NaN               NaN          29234.0
# 323                             NaN               NaN          29753.0
# 333                             NaN               NaN          29807.0
# 338                             NaN               NaN          29836.0
#
#                     WeaponTwoDescriptorId  TurretThreeID  MovementSelectorID  \
# 190  00000000-0000-0000-0600-00005b040000            NaN               16975
# 235  00000000-0000-0000-0600-0000ba060000            NaN               16868
# 323  00000000-0000-0000-0600-000013070000            NaN               18638
# 333  00000000-0000-0000-0600-0000b8040000            NaN               16992
# 338                                   NaN            NaN               18738
#
#      WeaponThreeDispersionAtMinRange  WeaponFourPorteeMaximale  \
# 190                              NaN                       NaN
# 235                              NaN                       NaN
# 323                              NaN                       NaN
# 333                              NaN                       NaN
# 338                              NaN                       NaN
#
#      WeaponThreeAnimateOnlyOneSoldier  WeaponOnePorteeMinimaleProjectile  \
# 190                               NaN                                NaN
# 235                               NaN                                NaN
# 323                               NaN                                NaN
# 333                               NaN                                NaN
# 338                               NaN                                NaN
#
#     WeaponThreeTirReflexe WeaponOneTempsEntreDeuxTirs  WeaponFourArme  \
# 190                   NaN                           1             NaN
# 235                   NaN                         0.8             NaN
# 323                   NaN                           1             NaN
# 333                   NaN                           1             NaN
# 338                   NaN                           1             NaN
#
#      WeaponFourMissileTimeBetweenCorrections  WeaponFourRandomDispersion  \
# 190                                      NaN                         NaN
# 235                                      NaN                         NaN
# 323                                      NaN                         NaN
# 333                                      NaN                         NaN
# 338                                      NaN                         NaN
#
#     WeaponThreeAffichageMenu WeaponOneTempsEntreDeuxFx  \
# 190                      NaN                         1
# 235                      NaN                       0.2
# 323                      NaN                         1
# 333                      NaN                         1
# 338                      NaN                         1
#
#      WeaponFourNeedModelChange  WeaponFourRadiusSplashPhysicalDamages  \
# 190                        NaN                                    NaN
# 235                        NaN                                    NaN
# 323                        NaN                                    NaN
# 333                        NaN                                    NaN
# 338                        NaN                                    NaN
#
#     WeaponThreeFireTriggeringProbability  WeaponFourLevel  \
# 190                                  NaN              NaN
# 235                                  NaN              NaN
# 323                                  NaN              NaN
# 333                                  NaN              NaN
# 338                                  NaN              NaN
#
#                    TurretTwoType  WeaponFourPuissance WeaponThreeCaliber  \
# 190  TTurretInfanterieDescriptor                  NaN                NaN
# 235     TTurretTwoAxisDescriptor                  NaN                NaN
# 323                          NaN                  NaN                NaN
# 333  TTurretInfanterieDescriptor                  NaN                NaN
# 338                          NaN                  NaN                NaN
#
#     WeaponOneAffecteParNombre  WeaponTwoRadiusSplashSuppressDamages  \
# 190                       NaN                                 520.0
# 235                       NaN                                7800.0
# 323                       NaN                                4940.0
# 333                       NaN                                 520.0
# 338                       NaN                                   NaN
#
#      WeaponFourPorteeMinimale  WeaponThreeNbTirParSalves  \
# 190                       NaN                        NaN
# 235                       NaN                        NaN
# 323                       NaN                        NaN
# 333                       NaN                        NaN
# 338                       NaN                        NaN
#
#     WeaponTwoTempsAnimation  WeaponOneRadiusSplashPhysicalDamages  \
# 190                     NaN                                 130.0
# 235                     NaN                                 156.0
# 323                     NaN                                 130.0
# 333                     NaN                                 130.0
# 338                     NaN                               10920.0
#
#     WeaponOneIsFireAndForget  WeaponTwoRadiusSplashPhysicalDamages  \
# 190                      NaN                                 156.0
# 235                      NaN                                2340.0
# 323                      NaN                                1482.0
# 333                      NaN                                 156.0
# 338                      NaN                                   NaN
#
#      WeaponOneAngleDispersion  WeaponThreeRadiusSplashSuppressDamages  \
# 190                     0.015                                     NaN
# 235                     0.010                                     NaN
# 323                     0.010                                     NaN
# 333                     0.015                                     NaN
# 338                     0.010                                     NaN
#
#      WeaponThreeNbrProjectilesSimultanes  WeaponFourMissileDescriptor  \
# 190                                  NaN                          NaN
# 235                                  NaN                          NaN
# 323                                  NaN                          NaN
# 333                                  NaN                          NaN
# 338                                  NaN                          NaN
#
#      WeaponTwoNoiseDissimulationMalus  TurretOneID  \
# 190                             1.762      39401.0
# 235                             2.200      39639.0
# 323                             1.760      40106.0
# 333                             2.250      40157.0
# 338                               NaN      40181.0
#
#      WeaponThreeRadiusSplashPhysicalDamages WeaponFourTypeName  \
# 190                                     NaN                NaN
# 235                                     NaN                NaN
# 323                                     NaN                NaN
# 333                                     NaN                NaN
# 338                                     NaN                NaN
#
#      WeaponFourTempsDeVisee  WeaponTwoIsSubAmmunition  DamageModuleID  \
# 190                     NaN                       NaN           27884
# 235                     NaN                       NaN           29235
# 323                     NaN                       NaN           27761
# 333                     NaN                       NaN           28190
# 338                     NaN                       NaN           27923
#
#      WeaponOneNbTirParSalves  WeaponFourEfficaciteSelonPortee  \
# 190                      1.0                              NaN
# 235                     10.0                              NaN
# 323                      1.0                              NaN
# 333                      1.0                              NaN
# 338                      2.0                              NaN
#
#      WeaponTwoTempsEntreDeuxFx  MovementModuleID  WeaponThreeSuppressDamages  \
# 190                        6.0             28192                         NaN
# 235                        1.0             28095                         NaN
# 323                        1.0             29748                         NaN
# 333                        4.0             28207                         NaN
# 338                        NaN             29837                         NaN
#
#     WeaponTwoArme  WeaponTwoAngleDispersion  WeaponFourSupplyCost  \
# 190           NaN                     0.010                   NaN
# 235             3                     0.005                   NaN
# 323             3                     0.010                   NaN
# 333           NaN                     0.010                   NaN
# 338           NaN                       NaN                   NaN
#
#     WeaponThreeFX_tir_tendu WeaponOneEfficaciteSelonPortee  \
# 190                     NaN                            NaN
# 235                     NaN                            NaN
# 323                     NaN                            NaN
# 333                     NaN                            NaN
# 338                     NaN                            NaN
#
#         TextureMotherCountryForInterface  \
# 190  CommonTexture_MotherCountryFlag_HOL
# 235  CommonTexture_MotherCountryFlag_HOL
# 323  CommonTexture_MotherCountryFlag_HOL
# 333  CommonTexture_MotherCountryFlag_HOL
# 338  CommonTexture_MotherCountryFlag_HOL
#
#     WeaponOneMissileTimeBetweenCorrections  \
# 190                                    NaN
# 235                                    NaN
# 323                                    NaN
# 333                                    NaN
# 338                                     10
#
#      WeaponOneAffichageMunitionParSalve WeaponThreeTypeArme  \
# 190                                 1.0                 NaN
# 235                               100.0                 NaN
# 323                                 1.0                 NaN
# 333                                 1.0                 NaN
# 338                                 2.0                 NaN
#
#     WeaponTwoPorteeMaximaleProjectile  WeaponOneTempsEntreDeuxSalves  \
# 190                               NaN                            6.0
# 235                               NaN                            2.0
# 323                               NaN                            8.0
# 333                               NaN                            3.0
# 338                               NaN                           10.0
#
#     WeaponThreeArme  WeaponThreeSmokeDescriptor WeaponTwoSalvoStockIndex  \
# 190             NaN                         NaN                      NaN
# 235             NaN                         NaN                      NaN
# 323             NaN                         NaN                      NaN
# 333             NaN                         NaN                      NaN
# 338             NaN                         NaN                      NaN
#
#                                 WeaponTwoHitRollRule  \
# 190  113 : 77393 (False) - TModernWarfareHitRollRule
# 235  113 : 78451 (False) - TModernWarfareHitRollRule
# 323  113 : 77611 (False) - TModernWarfareHitRollRule
# 333  113 : 78110 (False) - TModernWarfareHitRollRule
# 338                                              NaN
#
#      WeaponThreeCorrectedShotDispersionMultiplier  WeaponFourRayonPinned  \
# 190                                           NaN                    NaN
# 235                                           NaN                    NaN
# 323                                           NaN                    NaN
# 333                                           NaN                    NaN
# 338                                           NaN                    NaN
#
#     WeaponOneTypeName WeaponThreePorteeMaximaleTBA SalvoWeaponTwoIsMain  \
# 190  0B06000000000000                          NaN                False
# 235  0B06000000000000                          NaN                False
# 323  0B06000000000000                          NaN                False
# 333  0B06000000000000                          NaN                False
# 338  0B06000000000000                          NaN                False
#
#      WeaponThreeWeaponCursorType  WeaponFourCorrectedShotDispersionMultiplier  \
# 190                          NaN                                          NaN
# 235                          NaN                                          NaN
# 323                          NaN                                          NaN
# 333                          NaN                                          NaN
# 338                          NaN                                          NaN
#
#      VitesseCombat WeaponFourHitRollRule  SalvosWeaponOne  \
# 190           1560                   NaN             10.0
# 235           3640                   NaN             35.0
# 323           3640                   NaN             30.0
# 333           2340                   NaN              4.0
# 338           4160                   NaN              5.0
#
#      WeaponFourPorteeMaximaleBateaux                 WeaponOneDescriptorId  \
# 190                              NaN  00000000-0000-0000-0600-000068080000
# 235                              NaN  00000000-0000-0000-0600-0000ff030000
# 323                              NaN  00000000-0000-0000-0600-000009060000
# 333                              NaN  00000000-0000-0000-0600-000018080000
# 338                              NaN  00000000-0000-0000-0600-0000c3090000
#
#      ExperienceModuleID WeaponOneAffichageMenu  WeaponThreeRandomDispersion  \
# 190               27756                   True                          NaN
# 235               27756                   True                          NaN
# 323               27756                   True                          NaN
# 333               27756                   True                          NaN
# 338               27756                   True                          NaN
#
#     WeaponThreeFX_tir_sans_physic                TurretOneType  \
# 190                           NaN  TTurretInfanterieDescriptor
# 235                           NaN     TTurretTwoAxisDescriptor
# 323                           NaN     TTurretTwoAxisDescriptor
# 333                           NaN  TTurretInfanterieDescriptor
# 338                           NaN     TTurretTwoAxisDescriptor
#
#      WeaponFourAmmunitionID  WeaponFourNbTirParSalves  \
# 190                     NaN                       NaN
# 235                     NaN                       NaN
# 323                     NaN                       NaN
# 333                     NaN                       NaN
# 338                     NaN                       NaN
#
#     WeaponOneDispersionAtMaxRange  SalvosWeaponTwo  \
# 190                           NaN              3.0
# 235                           NaN             26.0
# 323                           NaN             -1.0
# 333                           NaN              2.0
# 338                           NaN             -1.0
#
#                TextureTransportForInterface WeaponOnePorteeMinimaleTBA  \
# 190  78 : 17784 (True) - TUIResourceTexture                        NaN
# 235                                     NaN                        NaN
# 323                                     NaN                        NaN
# 333  78 : 18710 (True) - TUIResourceTexture                        NaN
# 338  78 : 16535 (True) - TUIResourceTexture                      41600
#
#     SalvoWeaponThreeIsMain  WeaponTwoRandomDispersion  \
# 190                  False                        NaN
# 235                  False                        NaN
# 323                  False                        NaN
# 333                  False                        NaN
# 338                  False                        NaN
#
#      WeaponThreePorteeMinimaleHA  WeaponTwoNbTirParSalves  \
# 190                          NaN                      3.0
# 235                          NaN                      1.0
# 323                          NaN                      1.0
# 333                          NaN                      1.0
# 338                          NaN                      NaN
#
#     WeaponFourAffichageMenu  WeaponFourIsSubAmmunition WeaponFourTirReflexe  \
# 190                     NaN                        NaN                  NaN
# 235                     NaN                        NaN                  NaN
# 323                     NaN                        NaN                  NaN
# 333                     NaN                        NaN                  NaN
# 338                     NaN                        NaN                  NaN
#
#                   WeaponTwoFireDescriptor  WeaponThreeAffecteParNombre  \
# 190                                   NaN                          NaN
# 235  82 : 27774 (True) - TUniteDescriptor                          NaN
# 323  82 : 27774 (True) - TUniteDescriptor                          NaN
# 333                                   NaN                          NaN
# 338                                   NaN                          NaN
#
#      WeaponOneRandomDispersion  WeaponTwoPuissance WeaponTwoMissileDescriptor  \
# 190                        NaN                10.0                        NaN
# 235                        NaN               260.0                        NaN
# 323                        NaN               260.0                        NaN
# 333                        NaN                16.0                        NaN
# 338                        NaN                 NaN                        NaN
#
#      WeaponFourAffecteParNombre TurretThreeType WeaponFourName  \
# 190                         NaN             NaN            NaN
# 235                         NaN             NaN            NaN
# 323                         NaN             NaN            NaN
# 333                         NaN             NaN            NaN
# 338                         NaN             NaN            NaN
#
#      WeaponThreePorteeMaximaleHA  WeaponThreeTirEnMouvement  \
# 190                          NaN                        NaN
# 235                          NaN                        NaN
# 323                          NaN                        NaN
# 333                          NaN                        NaN
# 338                          NaN                        NaN
#
#      WeaponFourDispersionAtMaxRange WeaponOneTirIndirect  DamageSelectorID  \
# 190                             NaN                  NaN             16648
# 235                             NaN                  NaN             18088
# 323                             NaN                  NaN             16520
# 333                             NaN                  NaN             16973
# 338                             NaN                  NaN             16693
#
#     WeaponTwoAnimateOnlyOneSoldier WeaponOnePhysicalDamages  \
# 190                            NaN                        1
# 235                            NaN                      0.5
# 323                            NaN                        1
# 333                            NaN                        1
# 338                            NaN                        6
#
#      WeaponFourPhysicalDamages  WeaponFourAffichageMunitionParSalve  \
# 190                        NaN                                  NaN
# 235                        NaN                                  NaN
# 323                        NaN                                  NaN
# 333                        NaN                                  NaN
# 338                        NaN                                  NaN
#
#     WeaponThreeHitRollRule  WeaponThreeAngleDispersion  \
# 190                    NaN                         NaN
# 235                    NaN                         NaN
# 323                    NaN                         NaN
# 333                    NaN                         NaN
# 338                    NaN                         NaN
#
#      WeaponTwoTempsEntreDeuxTirs WeaponTwoPorteeMaximale  SalvosWeaponThree  \
# 190                          6.0                     130               -1.0
# 235                          1.0                  169000               -1.0
# 323                          1.0                  117000               -1.0
# 333                          4.0                   78000               50.0
# 338                          NaN                     NaN               -1.0
#
#     WeaponOnePorteeMaximaleHA  WeaponThreeAmmunitionID  \
# 190                       NaN                      NaN
# 235                       NaN                      NaN
# 323                       NaN                      NaN
# 333                       NaN                      NaN
# 338                    260000                      NaN
#
#     WeaponTwoFireTriggeringProbability  WeaponTwoPorteeMinimaleProjectile  \
# 190                                NaN                                NaN
# 235                                0.1                                NaN
# 323                                0.1                                NaN
# 333                                NaN                                NaN
# 338                                NaN                                NaN
#
#      WeaponThreeIgnoreInflammabilityConditions WeaponOnePorteeMaximaleBateaux  \
# 190                                        NaN                          39000
# 235                                        NaN                          65000
# 323                                        NaN                         117000
# 333                                        NaN                          39000
# 338                                        NaN                            NaN
#
#      WeaponFourTempsEntreDeuxFx WeaponOnePorteeMinimaleBateaux  \
# 190                         NaN                            NaN
# 235                         NaN                            NaN
# 323                         NaN                            NaN
# 333                         NaN                            NaN
# 338                         NaN                            NaN
#
#      WeaponFourPorteeMinimaleProjectile  \
# 190                                 NaN
# 235                                 NaN
# 323                                 NaN
# 333                                 NaN
# 338                                 NaN
#
#     WeaponTwoMissileTimeBetweenCorrections WeaponFourFX_tir_tendu  \
# 190                                    NaN                    NaN
# 235                                    NaN                    NaN
# 323                                    NaN                    NaN
# 333                                    NaN                    NaN
# 338                                    NaN                    NaN
#
#      WeaponOneSuppressDamages  WeaponTwoPorteeMinimaleHA  WeaponTwoLevel  \
# 190                     400.0                        NaN             3.0
# 235                      55.0                        NaN             3.0
# 323                      88.0                        NaN             3.0
# 333                     264.0                        NaN             3.0
# 338                     240.0                        NaN             NaN
#
#     WeaponTwoEfficaciteSelonPortee  WeaponThreeNoiseDissimulationMalus  \
# 190                            NaN                                 NaN
# 235                            NaN                                 NaN
# 323                            NaN                                 NaN
# 333                            NaN                                 NaN
# 338                            NaN                                 NaN
#
#      WeaponTwoTirEnMouvement WeaponOnePorteeMinimale  \
# 190                      NaN                     NaN
# 235                      NaN                     NaN
# 323                      NaN                     NaN
# 333                      NaN                     NaN
# 338                      NaN                     NaN
#
#      WeaponTwoPhysicalDamages  WeaponFourFX_frottement  \
# 190                       1.0                      NaN
# 235                       3.0                      NaN
# 323                       2.0                      NaN
# 333                       1.0                      NaN
# 338                       NaN                      NaN
#
#      WeaponFourTempsEntreDeuxTirs WeaponTwoFX_tir_sans_physic  \
# 190                           NaN                         NaN
# 235                           NaN                         NaN
# 323                           NaN                         NaN
# 333                           NaN                         NaN
# 338                           NaN                         NaN
#
#     WeaponThreeInterfaceWeaponTexture  WeaponFourSmokeDescriptor  \
# 190                               NaN                        NaN
# 235                               NaN                        NaN
# 323                               NaN                        NaN
# 333                               NaN                        NaN
# 338                               NaN                        NaN
#
#      WeaponThreeIsSubAmmunition WeaponOneTirEnMouvement  \
# 190                         NaN                     NaN
# 235                         NaN                     NaN
# 323                         NaN                     NaN
# 333                         NaN                     NaN
# 338                         NaN                     NaN
#
#     WeaponThreeNeedModelChange  \
# 190                        NaN
# 235                        NaN
# 323                        NaN
# 333                        NaN
# 338                        NaN
#
#                                 WeaponOneHitRollRule WeaponTwoTirIndirect  \
# 190  113 : 77500 (False) - TModernWarfareHitRollRule                  NaN
# 235  113 : 77977 (False) - TModernWarfareHitRollRule                  NaN
# 323  113 : 77611 (False) - TModernWarfareHitRollRule                  NaN
# 333  113 : 77549 (False) - TModernWarfareHitRollRule                  NaN
# 338  113 : 77369 (False) - TModernWarfareHitRollRule                  NaN
#
#      WeaponThreePhysicalDamages AutoOrientation  \
# 190                         NaN            True
# 235                         NaN            True
# 323                         NaN            True
# 333                         NaN            True
# 338                         NaN            True
#
#      WeaponFourIgnoreInflammabilityConditions  WeaponTwoTirContinu  \
# 190                                       NaN                  NaN
# 235                                       NaN                  NaN
# 323                                       NaN                  NaN
# 333                                       NaN                  NaN
# 338                                       NaN                  NaN
#
#      WeaponFourDispersionAtMinRange  \
# 190                             NaN
# 235                             NaN
# 323                             NaN
# 333                             NaN
# 338                             NaN
#
#      WeaponTwoCorrectedShotDispersionMultiplier  \
# 190                                         NaN
# 235                                         NaN
# 323                                         NaN
# 333                                         NaN
# 338                                         NaN
#
#             WeaponOneInterfaceWeaponTexture  \
# 190  78 : 78149 (True) - TUIResourceTexture
# 235  78 : 78453 (True) - TUIResourceTexture
# 323  78 : 78780 (True) - TUIResourceTexture
# 333  78 : 77699 (True) - TUIResourceTexture
# 338  78 : 77629 (True) - TUIResourceTexture
#
#     WeaponOneCorrectedShotDispersionMultiplier  \
# 190                                        NaN
# 235                                        NaN
# 323                                        NaN
# 333                                        NaN
# 338                                        NaN
#
#      WeaponFourNoiseDissimulationMalus  WeaponFourNbrProjectilesSimultanes  \
# 190                                NaN                                 NaN
# 235                                NaN                                 NaN
# 323                                NaN                                 NaN
# 333                                NaN                                 NaN
# 338                                NaN                                 NaN
#
#      WeaponThreePorteeMaximale  WeaponTwoNbrProjectilesSimultanes  \
# 190                        NaN                                1.0
# 235                        NaN                                1.0
# 323                        NaN                                1.0
# 333                        NaN                                1.0
# 338                        NaN                                NaN
#
#      ExperienceSelectorID               DeathExplosionAmmo  \
# 190                 16515  89 : 16551 (True) - TAmmunition
# 235                 16515  89 : 16656 (True) - TAmmunition
# 323                 16515  89 : 16551 (True) - TAmmunition
# 333                 16515  89 : 16551 (True) - TAmmunition
# 338                 16515  89 : 16551 (True) - TAmmunition
#
#      WeaponTwoAmmunitionID  WeaponThreeDispersionAtMaxRange  \
# 190                67690.0                              NaN
# 235                67952.0                              NaN
# 323                68429.0                              NaN
# 333                68483.0                              NaN
# 338                    NaN                              NaN
#
#     WeaponOneNeedModelChange  WeaponTwoAffichageMunitionParSalve  \
# 190                     True                                30.0
# 235                      NaN                                 1.0
# 323                      NaN                                 1.0
# 333                     True                                 1.0
# 338                      NaN                                 NaN
#
#      WeaponThreePorteeMaximaleProjectile StickToGround  \
# 190                                  NaN          True
# 235                                  NaN          True
# 323                                  NaN          True
# 333                                  NaN          True
# 338                                  NaN          True
#
#      WeaponFourPorteeMaximaleTBA  WeaponFourPorteeMaximaleHA  \
# 190                          NaN                         NaN
# 235                          NaN                         NaN
# 323                          NaN                         NaN
# 333                          NaN                         NaN
# 338                          NaN                         NaN
#
#      UnitDescriptorID  WeaponTwoInterdireTirReflexe  \
# 190             14862                           NaN
# 235             14907                           NaN
# 323             14995                           NaN
# 333             15005                           NaN
# 338             15010                           NaN
#
#             WeaponTwoInterfaceWeaponTexture  WeaponThreeSalvoStockIndex  \
# 190  78 : 78148 (True) - TUIResourceTexture                         NaN
# 235  78 : 78452 (True) - TUIResourceTexture                         NaN
# 323  78 : 78781 (True) - TUIResourceTexture                         NaN
# 333  78 : 78843 (True) - TUIResourceTexture                         NaN
# 338                                     NaN                         NaN
#
#      WeaponThreeTirIndirect  WeaponTwoTempsEntreDeuxSalves WeaponOneTypeArme  \
# 190                     NaN                           12.0  E162010000000000
# 235                     NaN                            6.6  D175010000000000
# 323                     NaN                            8.0  B31E95B36B5E0000
# 333                     NaN                            4.0  E162010000000000
# 338                     NaN                            NaN  D7D2010000000000
#
#      WeaponThreeAffichageMunitionParSalve WeaponFourFireDescriptor  \
# 190                                   NaN                      NaN
# 235                                   NaN                      NaN
# 323                                   NaN                      NaN
# 333                                   NaN                      NaN
# 338                                   NaN                      NaN
#
#     WeaponTwoIgnoreInflammabilityConditions  WeaponThreePorteeMinimaleTBA  \
# 190                                     NaN                           NaN
# 235                                     NaN                           NaN
# 323                                     NaN                           NaN
# 333                                     NaN                           NaN
# 338                                     NaN                           NaN
#
#     WeaponTwoGuidance  WeaponTwoFX_vitesse_de_depart WeaponOneArme  \
# 190               NaN                       180000.0            48
# 235               NaN                       140000.0           NaN
# 323               NaN                       140000.0            41
# 333               NaN                       180000.0            47
# 338               NaN                            NaN             3
#
#     WeaponOneFX_frottement WeaponTwoPorteeMinimaleBateaux  \
# 190                   0.01                            NaN
# 235                   0.01                            NaN
# 323                   0.01                            NaN
# 333                   0.01                           6500
# 338                    NaN                            NaN
#
#      WeaponThreeGuidance WeaponTwoAffichageMenu  WeaponFourGuidance  \
# 190                  NaN                   True                 NaN
# 235                  NaN                   True                 NaN
# 323                  NaN                   True                 NaN
# 333                  NaN                   True                 NaN
# 338                  NaN                    NaN                 NaN
#
#      VisibilityModuleID  FuelModuleSelectorID  WeaponThreeSupplyCost  \
# 190               27882                   NaN                    NaN
# 235               27758               18089.0                    NaN
# 323               27994               17808.0                    NaN
# 333               29073                   NaN                    NaN
# 338               27758               16805.0                    NaN
#
#      WeaponOneSmokeDescriptor WeaponTwoDispersionAtMaxRange  \
# 190                       NaN                           NaN
# 235                       NaN                           NaN
# 323                       NaN                           NaN
# 333                       NaN                           NaN
# 338                       NaN                           NaN
#
#     WeaponOneTempsAnimation  WeaponOneLevel  WeaponOneFX_vitesse_de_depart  \
# 190                     NaN             3.0                        40000.0
# 235                     NaN             3.0                       180000.0
# 323                     NaN             2.0                       180000.0
# 333                     NaN             3.0                        40000.0
# 338                     NaN             1.0                       104000.0
#
#     WeaponTwoPorteeMaximaleBateaux WeaponTwoPorteeMaximaleHA  \
# 190                            130                       NaN
# 235                         169000                       NaN
# 323                         117000                       NaN
# 333                          78000                       NaN
# 338                            NaN                       NaN
#
#         WeaponTwoName  WeaponThreeTempsDeVisee  WeaponTwoSupplyCost  \
# 190  6ABCBA3711010000                      NaN                  3.0
# 235  333D9B6851580000                      NaN                 25.0
# 323  8675200000000000                      NaN                 10.0
# 333  42D4690000000000                      NaN                  6.0
# 338               NaN                      NaN                  NaN
#
#      WeaponOneSupplyCost WeaponFourDescriptorId  \
# 190                 20.0                    NaN
# 235                 20.0                    NaN
# 323                 10.0                    NaN
# 333                 15.0                    NaN
# 338                216.0                    NaN
#
#      WeaponOneNbrProjectilesSimultanes  WeaponFourRadiusSplashSuppressDamages  \
# 190                                1.0                                    NaN
# 235                                1.0                                    NaN
# 323                                1.0                                    NaN
# 333                                1.0                                    NaN
# 338                                1.0                                    NaN
#
#     WeaponOneSalvoStockIndex_ForInterface  WeaponFourTirIndirect
# 190                                   NaN                    NaN
# 235                                   NaN                    NaN
# 323                                   NaN                    NaN
# 333                                   NaN                    NaN
# 338                                   NaN                    NaN

# %%
mc_map = {
    'URSS': 'Soviet Union',
    'US': 'United States',
    'RDA': 'East Germany',
    'POL': 'Poland',
    'CHI': 'China',
    'NK': 'North Korea',
    'TCH': 'Czechoslovakia',
    'ISR': 'Israel',
    'UK': 'United Kingdom',
    'FR': 'France',
    'RFA': 'West Germany',
    'ROK': 'South Korea',
    'HOL': 'Netherlands',
    'ANZ': 'ANZAC',
    'CAN': 'Canada',
    'SWE': 'Sweden',
    'JAP': 'Japan',
    'DAN': 'Denmark',
    'NOR': 'Norway'    
}

wargame['MotherCountry'] = wargame['MotherCountry'].map(mc_map)

# %%
wargame['MovementType'].value_counts(dropna=False)
# Out:
# TMouvementHandlerLandVehicleDescriptor    1370
# TMouvementHandlerAirplaneDescriptor        229
# TMouvementHandlerHelicopterDescriptor      219
# Name: MovementType, dtype: int64

# %%
mv_map = {
    'TMouvementHandlerLandVehicleDescriptor': 'Land',
    'TMouvementHandlerAirplaneDescriptor': 'Airplane',
    'TMouvementHandlerHelicopterDescriptor': 'Helicopter'
}

wargame['MovementType'] = wargame['MovementType'].map(mv_map)

# %%
wargame['Transporter'] = wargame['Transporter'].map(lambda v: False if pd.isnull(v) else True)
wargame['IsTargetableAsBoat'] = wargame['IsTargetableAsBoat'].map(lambda v: False if pd.isnull(v) else True)

# %%
wargame = wargame.rename(columns={'MaxDamages': 'Health'})

# %%
wargame = wargame.rename(columns={'IsPrototype': 'Prototype'})

# %% [markdown]
# ## Undecided question:
#
# Which of these stats is the real one?

# %%
wargame['ManageUnitOrientation'].value_counts(dropna=False)
# Out:
# True    1522
# NaN      296
# Name: ManageUnitOrientation, dtype: int64

# %%
wargame['AutoOrientation'].value_counts(dropna=False)
# Out:
# True    1786
# NaN       32
# Name: AutoOrientation, dtype: int64

# %%
wargame = wargame.T.drop_duplicates().T

# %%
wargame['HitRollSizeModifier'] = wargame['HitRollSizeModifier'].map(lambda v: v if pd.notnull(v) else 0).astype(float)
wargame['HitRollECMModifier'] = wargame['HitRollECMModifier'].map(lambda v: v if pd.notnull(v) else 0).astype(float)

# %% [markdown]
# ## Undecided question:
#
# What does this mean?

# %%
wargame['TerrainsToIgnoreMask'].value_counts()
# Out:
# 26    10
# 16    10
# 24    10
# Name: TerrainsToIgnoreMask, dtype: int64

# %%
del wargame['UpgradeRequire']

# %%
del wargame['TextureForInterface']

# %%
wargame.head(5)
# Out:
#           UnitName   MotherCountry ProductionPrice ProductionYear Health  \
# 0             Dana  Czechoslovakia              90           1977     10
# 1        Rzp Kub-M          Poland              45           1976     10
# 2  2K22 Tunguska-M    Soviet Union             100           1986     10
# 3    2K22 Tunguska    Soviet Union              85           1982     10
# 4       2S15 Norov    Soviet Union              35           1980     10
#
#   Prototype ManageUnitOrientation CanDeploySmoke CanWinExperience  \
# 0     False                  True           True             True
# 1     False                  True          False             True
# 2     False                  True          False             True
# 3     False                  True          False             True
# 4      True                  True          False             True
#
#   ExperienceGainBySecond UnitMovingType MovementType SpeedBonusOnRoad  \
# 0                    0.1              3         Land            0.875
# 1                    0.1              5         Land         1.444444
# 2                    0.1              5         Land        0.8333333
# 3                    0.1              5         Land        0.8333333
# 4                    0.1              8         Land        0.8333333
#
#   Maxspeed FuelCapacity FuelMoveDuration Transporter IsTargetableAsBoat  \
# 0     4160          500              750       False              False
# 1     2340          500              250       False              False
# 2     3120          500              500       False              False
# 3     3120          500              500       False              False
# 4     3120          350              600       False              False
#
#   TerrainsToIgnoreMask RookieDeployableAmount TrainedDeployableAmount  \
# 0                  NaN                      0                       4
# 1                  NaN                      0                       8
# 2                  NaN                      0                       4
# 3                  NaN                      0                       5
# 4                  NaN                      0                      16
#
#   HardenedDeployableAmount VeteranDeployableAmount EliteDeployableAmount  \
# 0                        3                       0                     0
# 1                        6                       0                     0
# 2                        3                       0                     0
# 3                        4                       0                     0
# 4                       12                       0                     0
#
#   UnitStealthBonus  HitRollSizeModifier  HitRollECMModifier FlyingAltitude  \
# 0                1                 0.05                 0.0            NaN
# 1                1                 0.05                 0.0            NaN
# 2                1                 0.00                 0.0            NaN
# 3                1                 0.00                 0.0            NaN
# 4                1                 0.00                 0.0            NaN
#
#   MinimalAltitude GunMuzzleSpeed CyclicManoeuvrability GFactorLimit  \
# 0             NaN            NaN                   NaN          NaN
# 1             NaN            NaN                   NaN          NaN
# 2             NaN            NaN                   NaN          NaN
# 3             NaN            NaN                   NaN          NaN
# 4             NaN            NaN                   NaN          NaN
#
#   LateralSpeed Mass MaxInclination RotorArea TorqueManoeuvrability  \
# 0          NaN  NaN            NaN       NaN                   NaN
# 1          NaN  NaN            NaN       NaN                   NaN
# 2          NaN  NaN            NaN       NaN                   NaN
# 3          NaN  NaN            NaN       NaN                   NaN
# 4          NaN  NaN            NaN       NaN                   NaN
#
#   UpwardsSpeed TempsDemiTour MaxAcceleration MaxDeceleration  \
# 0          NaN             6            1300            2600
# 1          NaN             4            1300            2600
# 2          NaN             3            1300            2600
# 3          NaN             3            1300            2600
# 4          NaN             6            1300            2600
#
#   WeaponSabordAngle        AliasName      ClassNameForDebug  \
# 0               NaN             DANA   Unit_152mm_SpGH_Dana
# 1               NaN        RZP KUB-M          Unit_2K12_Kub
# 2               NaN  2K22 TUNGUSKA-M  Unit_2K22M_Tunguska_M
# 3               NaN    2K22 TUNGUSKA     Unit_2K22_Tunguska
# 4               NaN       2S15 NOROV        Unit_2S15_Norov
#
#                  _ShortDatabaseName   NameInMenuToken Factory IconeType  \
# 0   Descriptor_Unit_152mm_SpGH_Dana  8E14D59D2C0F8600      13         2
# 1          Descriptor_Unit_2K12_Kub  A75E0D4235000000      13         3
# 2  Descriptor_Unit_2K22M_Tunguska_M  3A3BEBDE350CD500      13         3
# 3     Descriptor_Unit_2K22_Tunguska  B8CECEBA370CD500      13         3
# 4        Descriptor_Unit_2S15_Norov  3B7DD39821740300       8         1
#
#   MaxPacks Nationalite PositionInMenu TypeForAcknow VehicleSubType  Key  \
# 0        2           1              4           119              1  NaN
# 1        2           1             12           123            NaN  NaN
# 2        2           1             12           123            NaN  NaN
# 3        2           1             11           123            NaN  NaN
# 4        1           1             10           101              3  NaN
#
#   CoutEtoile                             UpgradeRequire ProductionTime  \
# 0          2                                        NaN             10
# 1          3                                        NaN             10
# 2          3  81 : 14675 (True) - TUniteAuSolDescriptor             10
# 3          2  81 : 15948 (True) - TUniteAuSolDescriptor             10
# 4          1  81 : 15630 (True) - TUniteAuSolDescriptor             10
#
#   Category AcknowUnitType                          DescriptorId MaxHPForHUD  \
# 0        3             32  00000000-0000-0000-0000-0000e8030000          10
# 1        5             30  00000000-0000-0000-0000-0000e9030000          10
# 2        5             31  00000000-0000-0000-0000-0000ea030000          10
# 3        5             31  00000000-0000-0000-0000-0000eb030000          10
# 4        3             22  00000000-0000-0000-0000-0000ec030000          10
#
#   WeaponThreeFX_frottement WeaponTwoPorteeMinimale  \
# 0                     0.01                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
#   WeaponTwoSalvoStockIndex_ForInterface WeaponTwoIsFireAndForget  \
# 0                                   NaN                      NaN
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
#
#   WeaponTwoSuppressDamages WeaponOneDispersionAtMinRange  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      280                           NaN
# 3                      280                           NaN
# 4                      115                           NaN
#
#   WeaponTwoTempsDeVisee WeaponOneSalvoStockIndex WeaponTwoTypeName  \
# 0                   NaN                      NaN               NaN
# 1                   NaN                      NaN               NaN
# 2                     1                      NaN  0B06000000000000
# 3                     1                      NaN  0B06000000000000
# 4                   1.4                      NaN  0B06000000000000
#
#   WeaponManagerModuleSelectorID WeaponTwoTirReflexe  \
# 0                         16519                 NaN
# 1                         16541                 NaN
# 2                         16556                True
# 3                         16565                True
# 4                         16572                True
#
#   WeaponOneNoiseDissimulationMalus WeaponOneRayonPinned  \
# 0                            1.254                  260
# 1                                2                26000
# 2                              5.2                  130
# 3                              5.2                  130
# 4                                2                 2080
#
#   WeaponOnePorteeMaximaleTBA WeaponOnePorteeMaximale KillExperienceBonus  \
# 0                      65000                   78000                 2.5
# 1                     182000                     NaN                 2.5
# 2                     208000                   78000                 2.5
# 3                     208000                   78000                 2.5
# 4                        NaN                  156000                 2.5
#
#   WeaponOneFX_tir_sans_physic                     TextureForInterface  \
# 0                         NaN  78 : 16534 (True) - TUIResourceTexture
# 1                        True  78 : 16552 (True) - TUIResourceTexture
# 2                         NaN  78 : 16561 (True) - TUIResourceTexture
# 3                         NaN  78 : 16566 (True) - TUIResourceTexture
# 4                         NaN  78 : 16579 (True) - TUIResourceTexture
#
#   WeaponFourTempsEntreDeuxSalves WeaponFourCaliber  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
#
#   WeaponOneIgnoreInflammabilityConditions  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   WeaponThreeMissileTimeBetweenCorrections WeaponOneAmmunitionID  \
# 0                                      NaN                 66544
# 1                                      NaN                 66569
# 2                                      NaN                 66580
# 3                                      NaN                 66580
# 4                                      NaN                 66597
#
#   WeaponOneTempsDeVisee WeaponOneGuidance WeaponTwoFX_frottement  \
# 0                     1               NaN                    NaN
# 1                   0.2                 1                    NaN
# 2                     1                 1                    NaN
# 3                     1                 1                    NaN
# 4                     1               NaN                   0.01
#
#                 WeaponThreeDescriptorId VisibilitySelectorID  \
# 0  00000000-0000-0000-0600-000046060000                16517
# 1                                   NaN                16517
# 2                                   NaN                16517
# 3                                   NaN                16517
# 4                                   NaN                16517
#
#   WeaponOneFireDescriptor  WeaponOneCaliber WeaponFourTypeArme  \
# 0                     NaN  B28C948300000000                NaN
# 1                     NaN  B7999A1C00000000                NaN
# 2                     NaN  A9C9C97240000000                NaN
# 3                     NaN  A9C9C97240000000                NaN
# 4                     NaN  B21C040200000000                NaN
#
#   WeaponTwoPorteeMaximaleTBA WeaponTwoRayonPinned  WeaponTwoCaliber  \
# 0                        NaN                  NaN               NaN
# 1                        NaN                  NaN               NaN
# 2                     247000                26000  5D66354B07000000
# 3                     221000                26000  5D66354B07000000
# 4                        NaN                 7800  B21C040200000000
#
#   WeaponOneRadiusSplashSuppressDamages WeaponTwoFX_tir_tendu  \
# 0                                  832                   NaN
# 1                                32760                   NaN
# 2                                 3770                   NaN
# 3                                 3770                   NaN
# 4                                13000                  True
#
#   WeaponTwoTypeArme            WeaponOneMissileDescriptor WeaponOneTirContinu  \
# 0               NaN                                   NaN                 NaN
# 1               NaN  82 : 77345 (True) - TUniteDescriptor                 NaN
# 2  D7D2010000000000                                   NaN                 NaN
# 3  D7D2010000000000                                   NaN                 NaN
# 4  B31E95B36B5E0000                                   NaN                 NaN
#
#   WeaponThreePorteeMinimale WeaponOneProjectileType  \
# 0                       NaN                     NaN
# 1                       NaN                       5
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#   WeaponThreeEfficaciteSelonPortee TurretTwoID WeaponFourAngleDispersion  \
# 0                              NaN       38485                       NaN
# 1                              NaN         NaN                       NaN
# 2                              NaN         NaN                       NaN
# 3                              NaN         NaN                       NaN
# 4                              NaN         NaN                       NaN
#
#   WeaponTwoAffecteParNombre WeaponThreePorteeMaximaleBateaux  \
# 0                       NaN                           143000
# 1                       NaN                              NaN
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
#
#     WeaponThreeName WeaponTwoNeedModelChange  \
# 0  0822556D07000000                      NaN
# 1               NaN                      NaN
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
#
#   WeaponOneFireTriggeringProbability     WeaponOneName  \
# 0                                NaN  558B3BC820000000
# 1                                NaN  07415C0A00000000
# 2                                NaN  57422C0300000000
# 3                                NaN  57422C0300000000
# 4                                NaN  4120ECF44D630000
#
#   WeaponOnePorteeMinimaleHA WeaponFourFireTriggeringProbability  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#   WeaponOneWeaponCursorType WeaponThreeTypeName WeaponThreeTempsEntreDeuxFx  \
# 0                         6    0B06000000000000                           1
# 1                         3                 NaN                         NaN
# 2                         5                 NaN                         NaN
# 3                         5                 NaN                         NaN
# 4                         4                 NaN                         NaN
#
#   WeaponThreeTempsEntreDeuxTirs WeaponThreeTempsEntreDeuxSalves  \
# 0                             1                              10
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#   WeaponOnePuissance WeaponThreeProjectileType TurretNoneType  \
# 0                 16                       NaN            NaN
# 1                500                       NaN            NaN
# 2                 14                       NaN            NaN
# 3                 14                       NaN            NaN
# 4                250                       NaN            NaN
#
#   WeaponThreeFX_vitesse_de_depart SalvoWeaponOneIsMain  \
# 0                          180000                False
# 1                             NaN                False
# 2                             NaN                False
# 3                             NaN                False
# 4                             NaN                False
#
#   WeaponFourInterfaceWeaponTexture WeaponThreeMissileDescriptor  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#   WeaponThreePuissance WeaponThreeRayonPinned WeaponThreeFireDescriptor  \
# 0                  250                   2080                       NaN
# 1                  NaN                    NaN                       NaN
# 2                  NaN                    NaN                       NaN
# 3                  NaN                    NaN                       NaN
# 4                  NaN                    NaN                       NaN
#
#   WeaponOneFX_tir_tendu WeaponFourWeaponCursorType WeaponOneIsSubAmmunition  \
# 0                  True                        NaN                      NaN
# 1                   NaN                        NaN                      NaN
# 2                  True                        NaN                      NaN
# 3                  True                        NaN                      NaN
# 4                  True                        NaN                      NaN
#
#   WeaponOneAnimateOnlyOneSoldier TurretNoneID WeaponTwoProjectileType  \
# 0                            NaN          NaN                     NaN
# 1                            NaN          NaN                     NaN
# 2                            NaN          NaN                       5
# 3                            NaN          NaN                       5
# 4                            NaN          NaN                     NaN
#
#   WeaponTwoWeaponCursorType WeaponFourSuppressDamages  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                         3                       NaN
# 3                         3                       NaN
# 4                         4                       NaN
#
#   WeaponOnePorteeMaximaleProjectile WeaponTwoDispersionAtMinRange  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
#
#   WeaponOneTirReflexe WeaponFourFX_vitesse_de_depart WeaponThreeLevel  \
# 0                True                            NaN                2
# 1                True                            NaN              NaN
# 2                True                            NaN              NaN
# 3                True                            NaN              NaN
# 4                True                            NaN              NaN
#
#   WeaponManagerID                 WeaponTwoDescriptorId TurretThreeID  \
# 0           27760                                   NaN           NaN
# 1           27780                                   NaN           NaN
# 2           27794  00000000-0000-0000-0600-00008b090000           NaN
# 3           27803  00000000-0000-0000-0600-00008a090000           NaN
# 4           27809  00000000-0000-0000-0600-00006f060000           NaN
#
#   MovementSelectorID WeaponFourPorteeMaximale WeaponThreeTirReflexe  \
# 0              16522                      NaN                  True
# 1              16543                      NaN                   NaN
# 2              16557                      NaN                   NaN
# 3              16557                      NaN                   NaN
# 4              16573                      NaN                   NaN
#
#   WeaponOneTempsEntreDeuxTirs WeaponFourArme WeaponOneTempsEntreDeuxFx  \
# 0                         0.8            NaN                       0.2
# 1                           1            NaN                         1
# 2                         0.2            NaN                     0.012
# 3                         0.2            NaN                     0.012
# 4                           5            NaN                         5
#
#   WeaponFourRadiusSplashPhysicalDamages WeaponThreeFireTriggeringProbability  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   WeaponFourLevel             TurretTwoType WeaponFourPuissance  \
# 0             NaN  TTurretTwoAxisDescriptor                 NaN
# 1             NaN                       NaN                 NaN
# 2             NaN                       NaN                 NaN
# 3             NaN                       NaN                 NaN
# 4             NaN                       NaN                 NaN
#
#   WeaponThreeCaliber WeaponOneAffecteParNombre  \
# 0   DEF248B23C180200                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
# 3                NaN                       NaN
# 4                NaN                       NaN
#
#   WeaponTwoRadiusSplashSuppressDamages WeaponThreeNbTirParSalves  \
# 0                                  NaN                         1
# 1                                  NaN                       NaN
# 2                                25480                       NaN
# 3                                25480                       NaN
# 4                                 6500                       NaN
#
#   WeaponTwoTempsAnimation WeaponOneRadiusSplashPhysicalDamages  \
# 0                     NaN                                  260
# 1                     NaN                                16380
# 2                     NaN                                  598
# 3                     NaN                                  598
# 4                     NaN                                  130
#
#   WeaponOneIsFireAndForget WeaponTwoRadiusSplashPhysicalDamages  \
# 0                      NaN                                  NaN
# 1                      NaN                                  NaN
# 2                      NaN                                12740
# 3                      NaN                                12740
# 4                      NaN                                 1950
#
#   WeaponOneAngleDispersion WeaponThreeRadiusSplashSuppressDamages  \
# 0                     0.01                                  19760
# 1                     0.01                                    NaN
# 2                    0.002                                    NaN
# 3                    0.002                                    NaN
# 4                     0.01                                    NaN
#
#   WeaponTwoNoiseDissimulationMalus TurretOneID  \
# 0                              NaN       38484
# 1                              NaN       38519
# 2                                2       38526
# 3                                2       38530
# 4                                2       38535
#
#   WeaponThreeRadiusSplashPhysicalDamages WeaponFourTypeName  \
# 0                                    130                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
# 4                                    NaN                NaN
#
#   WeaponFourTempsDeVisee DamageModuleID WeaponOneNbTirParSalves  \
# 0                    NaN          27761                      10
# 1                    NaN          27781                       3
# 2                    NaN          27761                      30
# 3                    NaN          27761                      30
# 4                    NaN          27761                      22
#
#   WeaponTwoTempsEntreDeuxFx MovementModuleID WeaponThreeSuppressDamages  \
# 0                       NaN            27763                        175
# 1                       NaN            27782                        NaN
# 2                         3            27795                        NaN
# 3                         3            27795                        NaN
# 4                         5            27810                        NaN
#
#   WeaponTwoArme WeaponTwoAngleDispersion WeaponFourSupplyCost  \
# 0           NaN                      NaN                  NaN
# 1           NaN                      NaN                  NaN
# 2             3                     0.01                  NaN
# 3             3                     0.01                  NaN
# 4             3                     0.01                  NaN
#
#   WeaponThreeFX_tir_tendu WeaponOneEfficaciteSelonPortee  \
# 0                    True                            NaN
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                           True
#
#              TextureMotherCountryForInterface  \
# 0  Typeface3D_TitleMono_CompensatePostProcess
# 1                                     Zoom123
# 2                   MaterialInterface2D_Blend
# 3                   MaterialInterface2D_Blend
# 4                   MaterialInterface2D_Blend
#
#   WeaponOneMissileTimeBetweenCorrections WeaponOneAffichageMunitionParSalve  \
# 0                                    NaN                                100
# 1                                     10                                  3
# 2                                    NaN                                500
# 3                                    NaN                                500
# 4                                    NaN                                 22
#
#   WeaponThreeTypeArme WeaponTwoPorteeMaximaleProjectile  \
# 0    B31E95B36B5E0000                               NaN
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 NaN                               NaN
# 4                 NaN                               NaN
#
#   WeaponOneTempsEntreDeuxSalves WeaponThreeArme  \
# 0                             3              41
# 1                            25             NaN
# 2                             5             NaN
# 3                             5             NaN
# 4                             5             NaN
#
#                               WeaponTwoHitRollRule WeaponFourRayonPinned  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2  113 : 77369 (False) - TModernWarfareHitRollRule                   NaN
# 3  113 : 77372 (False) - TModernWarfareHitRollRule                   NaN
# 4  113 : 77387 (False) - TModernWarfareHitRollRule                   NaN
#
#   WeaponOneTypeName WeaponThreePorteeMaximaleTBA SalvoWeaponTwoIsMain  \
# 0  0B06000000000000                          NaN                False
# 1  0B06000000000000                          NaN                False
# 2  0B06000000000000                          NaN                False
# 3  0B06000000000000                          NaN                False
# 4  0B06000000000000                          NaN                False
#
#   WeaponThreeWeaponCursorType VitesseCombat WeaponFourHitRollRule  \
# 0                           4          4160                   NaN
# 1                         NaN          2340                   NaN
# 2                         NaN          3120                   NaN
# 3                         NaN          3120                   NaN
# 4                         NaN          3120                   NaN
#
#   SalvosWeaponOne                 WeaponOneDescriptorId ExperienceModuleID  \
# 0               5  00000000-0000-0000-0600-0000e9030000              27756
# 1               1  00000000-0000-0000-0600-00008e090000              27756
# 2               4  00000000-0000-0000-0600-0000a6070000              27756
# 3               4  00000000-0000-0000-0600-0000a6070000              27756
# 4               1  00000000-0000-0000-0600-00005c050000              27756
#
#   WeaponOneAffichageMenu WeaponThreeFX_tir_sans_physic  \
# 0                   True                           NaN
# 1                   True                           NaN
# 2                   True                           NaN
# 3                   True                           NaN
# 4                   True                           NaN
#
#               TurretOneType WeaponFourAmmunitionID  \
# 0  TTurretTwoAxisDescriptor                    NaN
# 1  TTurretTwoAxisDescriptor                    NaN
# 2  TTurretTwoAxisDescriptor                    NaN
# 3  TTurretTwoAxisDescriptor                    NaN
# 4  TTurretTwoAxisDescriptor                    NaN
#
#   WeaponOneDispersionAtMaxRange SalvosWeaponTwo  \
# 0                           NaN              10
# 1                           NaN              -1
# 2                           NaN               1
# 3                           NaN               1
# 4                           NaN              -1
#
#              TextureTransportForInterface WeaponOnePorteeMinimaleTBA  \
# 0  78 : 16535 (True) - TUIResourceTexture                        NaN
# 1                                     NaN                      36400
# 2                                     NaN                        NaN
# 3                                     NaN                        NaN
# 4                                     NaN                        NaN
#
#   SalvoWeaponThreeIsMain WeaponTwoNbTirParSalves  \
# 0                  False                     NaN
# 1                  False                     NaN
# 2                  False                       8
# 3                  False                       8
# 4                  False                      22
#
#                 WeaponTwoFireDescriptor WeaponTwoPuissance  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                500
# 3                                   NaN                500
# 4  82 : 27774 (True) - TUniteDescriptor                260
#
#              WeaponTwoMissileDescriptor TurretThreeType WeaponFourName  \
# 0                                   NaN             NaN            NaN
# 1                                   NaN             NaN            NaN
# 2  82 : 77370 (True) - TUniteDescriptor             NaN            NaN
# 3  82 : 77373 (True) - TUniteDescriptor             NaN            NaN
# 4                                   NaN             NaN            NaN
#
#   WeaponOneTirIndirect DamageSelectorID WeaponTwoAnimateOnlyOneSoldier  \
# 0                  NaN            16520                            NaN
# 1                  NaN            16542                            NaN
# 2                  NaN            16520                            NaN
# 3                  NaN            16520                            NaN
# 4                  NaN            16520                            NaN
#
#   WeaponOnePhysicalDamages                           WeaponThreeHitRollRule  \
# 0                     0.75  113 : 77326 (False) - TModernWarfareHitRollRule
# 1                        9                                              NaN
# 2                        1                                              NaN
# 3                        1                                              NaN
# 4                        1                                              NaN
#
#   WeaponThreeAngleDispersion WeaponTwoTempsEntreDeuxTirs  \
# 0                      0.005                         NaN
# 1                        NaN                         NaN
# 2                        NaN                           3
# 3                        NaN                           3
# 4                        NaN                           5
#
#   WeaponTwoPorteeMaximale SalvosWeaponThree WeaponOnePorteeMaximaleHA  \
# 0                     NaN                 4                       NaN
# 1                     NaN                -1                    286000
# 2                     NaN                -1                    195000
# 3                     NaN                -1                    195000
# 4                  156000                -1                       NaN
#
#   WeaponThreeAmmunitionID WeaponTwoFireTriggeringProbability  \
# 0                   66543                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                0.1
#
#   WeaponOnePorteeMaximaleBateaux WeaponFourTempsEntreDeuxFx  \
# 0                          78000                        NaN
# 1                            NaN                        NaN
# 2                          78000                        NaN
# 3                          78000                        NaN
# 4                         156000                        NaN
#
#   WeaponOnePorteeMinimaleBateaux WeaponTwoMissileTimeBetweenCorrections  \
# 0                            NaN                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                     10
# 3                            NaN                                     10
# 4                            NaN                                    NaN
#
#   WeaponOneSuppressDamages WeaponTwoLevel WeaponTwoEfficaciteSelonPortee  \
# 0                       90            NaN                            NaN
# 1                      360            NaN                            NaN
# 2                      120              1                            NaN
# 3                      120              1                            NaN
# 4                      115              3                            NaN
#
#   WeaponThreeNoiseDissimulationMalus WeaponOnePorteeMinimale  \
# 0                               2.52                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#   WeaponTwoPhysicalDamages WeaponFourTempsEntreDeuxTirs  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                        7                          NaN
# 3                        7                          NaN
# 4                        3                          NaN
#
#   WeaponTwoFX_tir_sans_physic       WeaponThreeInterfaceWeaponTexture  \
# 0                         NaN  78 : 77325 (True) - TUIResourceTexture
# 1                         NaN                                     NaN
# 2                        True                                     NaN
# 3                        True                                     NaN
# 4                         NaN                                     NaN
#
#   WeaponOneTirEnMouvement WeaponThreeNeedModelChange  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#                               WeaponOneHitRollRule WeaponTwoTirIndirect  \
# 0  113 : 77328 (False) - TModernWarfareHitRollRule                  NaN
# 1  113 : 77344 (False) - TModernWarfareHitRollRule                  NaN
# 2  113 : 77367 (False) - TModernWarfareHitRollRule                  NaN
# 3  113 : 77367 (False) - TModernWarfareHitRollRule                  NaN
# 4  113 : 77387 (False) - TModernWarfareHitRollRule                  NaN
#
#   WeaponThreePhysicalDamages AutoOrientation  \
# 0                          1            True
# 1                        NaN            True
# 2                        NaN            True
# 3                        NaN            True
# 4                        NaN            True
#
#           WeaponOneInterfaceWeaponTexture  \
# 0  78 : 77327 (True) - TUIResourceTexture
# 1  78 : 77343 (True) - TUIResourceTexture
# 2  78 : 77366 (True) - TUIResourceTexture
# 3  78 : 77366 (True) - TUIResourceTexture
# 4  78 : 77386 (True) - TUIResourceTexture
#
#   WeaponOneCorrectedShotDispersionMultiplier  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   WeaponFourNoiseDissimulationMalus ExperienceSelectorID  \
# 0                               NaN                16515
# 1                               NaN                16515
# 2                               NaN                16515
# 3                               NaN                16515
# 4                               NaN                16515
#
#                 DeathExplosionAmmo WeaponTwoAmmunitionID  \
# 0  89 : 16533 (True) - TAmmunition                 66542
# 1  89 : 16551 (True) - TAmmunition                   NaN
# 2  89 : 16533 (True) - TAmmunition                 66581
# 3  89 : 16533 (True) - TAmmunition                 66586
# 4  89 : 16533 (True) - TAmmunition                 66598
#
#   WeaponOneNeedModelChange WeaponTwoAffichageMunitionParSalve StickToGround  \
# 0                      NaN                                NaN          True
# 1                      NaN                                NaN          True
# 2                      NaN                                  8          True
# 3                      NaN                                  8          True
# 4                      NaN                                 22          True
#
#   WeaponFourPorteeMaximaleTBA UnitDescriptorID  \
# 0                         NaN            14672
# 1                         NaN            14673
# 2                         NaN            14674
# 3                         NaN            14675
# 4                         NaN            14676
#
#           WeaponTwoInterfaceWeaponTexture WeaponTwoTempsEntreDeuxSalves  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2  78 : 77368 (True) - TUIResourceTexture                            20
# 3  78 : 77371 (True) - TUIResourceTexture                            20
# 4  78 : 77388 (True) - TUIResourceTexture                             5
#
#   WeaponOneTypeArme WeaponThreeAffichageMunitionParSalve  \
# 0  D175010000000000                                    1
# 1  D7D2010000000000                                  NaN
# 2  74AE2FE5ECF21E00                                  NaN
# 3  74AE2FE5ECF21E00                                  NaN
# 4  B31E95B36B5E0000                                  NaN
#
#   WeaponFourFireDescriptor WeaponTwoIgnoreInflammabilityConditions  \
# 0                      NaN                                     NaN
# 1                      NaN                                     NaN
# 2                      NaN                                     NaN
# 3                      NaN                                     NaN
# 4                      NaN                                     NaN
#
#   WeaponTwoGuidance WeaponTwoFX_vitesse_de_depart WeaponOneArme  \
# 0               NaN                           NaN             1
# 1               NaN                           NaN             3
# 2               NaN                        104000             3
# 3               NaN                        104000             3
# 4               NaN                        140000            17
#
#   WeaponOneFX_frottement WeaponTwoPorteeMinimaleBateaux VisibilityModuleID  \
# 0                   0.01                            NaN              27758
# 1                    NaN                            NaN              27758
# 2                   0.01                            NaN              27758
# 3                   0.01                            NaN              27758
# 4                   0.01                            NaN              27758
#
#   FuelModuleSelectorID WeaponThreeSupplyCost WeaponOneTempsAnimation  \
# 0                16523                    30                     NaN
# 1                16544                   NaN                     NaN
# 2                16558                   NaN                     NaN
# 3                16558                   NaN                     NaN
# 4                16574                   NaN                     NaN
#
#   WeaponOneLevel WeaponOneFX_vitesse_de_depart WeaponTwoPorteeMaximaleBateaux  \
# 0              3                        180000                            NaN
# 1              1                         65000                            NaN
# 2              3                        180000                            NaN
# 3              3                        180000                            NaN
# 4              2                        180000                         156000
#
#   WeaponTwoPorteeMaximaleHA     WeaponTwoName WeaponThreeTempsDeVisee  \
# 0                       NaN               NaN                       1
# 1                       NaN               NaN                     NaN
# 2                    195000  9720109702000000                     NaN
# 3                    182000  82405C0A00000000                     NaN
# 4                       NaN  4120ECF44D630000                     NaN
#
#   WeaponTwoSupplyCost WeaponOneSupplyCost WeaponFourDescriptorId  \
# 0                 NaN                  20                    NaN
# 1                 NaN                 486                    NaN
# 2                 952                 500                    NaN
# 3                 868                 500                    NaN
# 4                 440                 440                    NaN
#
#   WeaponOneNbrProjectilesSimultanes WeaponFourRadiusSplashSuppressDamages  \
# 0                                 1                                   NaN
# 1                                 1                                   NaN
# 2                                 1                                   NaN
# 3                                 1                                   NaN
# 4                                 1                                   NaN
#
#   WeaponOneSalvoStockIndex_ForInterface
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
wargame['AcknowUnitType'].value_counts().plot(kind='bar')
